# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import xgboost as xgb
from xgboost import XGBClassifier, XGBRegressor
from xgboost import plot_importance
from catboost import CatBoostRegressor
from matplotlib import pyplot
import shap

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
from time import time
from tqdm import tqdm_notebook as tqdm
from collections import Counter
from scipy import stats
import lightgbm as lgb
from sklearn.metrics import cohen_kappa_score, mean_squared_error
from sklearn.model_selection import KFold, StratifiedKFold
import gc
import json
pd.set_option('display.max_columns', 1000)
# Out:
# /kaggle/input/data-science-bowl-2019/train.csv
# /kaggle/input/data-science-bowl-2019/train_labels.csv
# /kaggle/input/data-science-bowl-2019/specs.csv
# /kaggle/input/data-science-bowl-2019/test.csv
# /kaggle/input/data-science-bowl-2019/sample_submission.csv

# %% [markdown]
# # Objective
#
# * In the last notebook we create our baseline model including a feature selection part.
# * Cohen cappa score of 0.456 (lb) with a local cv score of 0.529
# * In this notebook we are going to add more features and remove others that i think they overfitt the train set and then check if our local cv score improve.
# * Next, we will check if this improvement aligns with the lb.

# %% [markdown]
# # Notes
# * Check the distribution of the target variable of the out of folds score and the prediction distribution. A good model should more or less have the same distribution.

# %%
def eval_qwk_lgb_regr(y_true, y_pred):
    """
    Fast cappa eval function for lgb.
    """
    dist = Counter(reduce_train['accuracy_group'])
    for k in dist:
        dist[k] /= len(reduce_train)
    reduce_train['accuracy_group'].hist()
    
    acum = 0
    bound = {}
    for i in range(3):
        acum += dist[i]
        bound[i] = np.percentile(y_pred, acum * 100)

    def classify(x):
        if x <= bound[0]:
            return 0
        elif x <= bound[1]:
            return 1
        elif x <= bound[2]:
            return 2
        else:
            return 3

    y_pred = np.array(list(map(classify, y_pred))).reshape(y_true.shape)

    return 'cappa', cohen_kappa_score(y_true, y_pred, weights='quadratic'), True

# %%
def cohenkappa(ypred, y):
    y = y.get_label().astype("int")
    ypred = ypred.reshape((4, -1)).argmax(axis = 0)
    loss = cohenkappascore(y, y_pred, weights = 'quadratic')
    return "cappa", loss, True

# %%
def read_data():
    print('Reading train.csv file....')
    train = pd.read_csv('/kaggle/input/data-science-bowl-2019/train.csv')
    print('Training.csv file have {} rows and {} columns'.format(train.shape[0], train.shape[1]))

    print('Reading test.csv file....')
    test = pd.read_csv('/kaggle/input/data-science-bowl-2019/test.csv')
    print('Test.csv file have {} rows and {} columns'.format(test.shape[0], test.shape[1]))

    print('Reading train_labels.csv file....')
    train_labels = pd.read_csv('/kaggle/input/data-science-bowl-2019/train_labels.csv')
    print('Train_labels.csv file have {} rows and {} columns'.format(train_labels.shape[0], train_labels.shape[1]))

    print('Reading specs.csv file....')
    specs = pd.read_csv('/kaggle/input/data-science-bowl-2019/specs.csv')
    print('Specs.csv file have {} rows and {} columns'.format(specs.shape[0], specs.shape[1]))

    print('Reading sample_submission.csv file....')
    sample_submission = pd.read_csv('/kaggle/input/data-science-bowl-2019/sample_submission.csv')
    print('Sample_submission.csv file have {} rows and {} columns'.format(sample_submission.shape[0], sample_submission.shape[1]))
    return train, test, train_labels, specs, sample_submission

# %%
def encode_title(train, test, train_labels):
    # encode title
    train['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), train['title'], train['event_code']))
    test['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), test['title'], test['event_code']))
    all_title_event_code = list(set(train["title_event_code"].unique()).union(test["title_event_code"].unique()))
    # make a list with all the unique 'titles' from the train and test set
    list_of_user_activities = list(set(train['title'].unique()).union(set(test['title'].unique())))
    # make a list with all the unique 'event_code' from the train and test set
    list_of_event_code = list(set(train['event_code'].unique()).union(set(test['event_code'].unique())))
    list_of_event_id = list(set(train['event_id'].unique()).union(set(test['event_id'].unique())))
    # make a list with all the unique worlds from the train and test set
    list_of_worlds = list(set(train['world'].unique()).union(set(test['world'].unique())))
    # create a dictionary numerating the titles
    activities_map = dict(zip(list_of_user_activities, np.arange(len(list_of_user_activities))))
    activities_labels = dict(zip(np.arange(len(list_of_user_activities)), list_of_user_activities))
    activities_world = dict(zip(list_of_worlds, np.arange(len(list_of_worlds))))
    assess_titles = list(set(train[train['type'] == 'Assessment']['title'].value_counts().index).union(set(test[test['type'] == 'Assessment']['title'].value_counts().index)))
    # replace the text titles with the number titles from the dict
    train['title'] = train['title'].map(activities_map)
    test['title'] = test['title'].map(activities_map)
    train['world'] = train['world'].map(activities_world)
    test['world'] = test['world'].map(activities_world)
    train_labels['title'] = train_labels['title'].map(activities_map)
    win_code = dict(zip(activities_map.values(), (4100*np.ones(len(activities_map))).astype('int')))
    # then, it set one element, the 'Bird Measurer (Assessment)' as 4110, 10 more than the rest
    win_code[activities_map['Bird Measurer (Assessment)']] = 4110
    # convert text into datetime
    train['timestamp'] = pd.to_datetime(train['timestamp'])
    test['timestamp'] = pd.to_datetime(test['timestamp'])
    
    
    return train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, activities_labels, assess_titles, list_of_event_id, all_title_event_code

# %%
# this is the function that convert the raw data into processed features
def get_data(user_sample, test_set=False):
    '''
    The user_sample is a DataFrame from train or test where the only one 
    installation_id is filtered
    And the test_set parameter is related with the labels processing, that is only requered
    if test_set=False
    '''
    # Constants and parameters declaration
    last_activity = 0
    
    user_activities_count = {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
    
    # new features: time spent in each activity
    last_session_time_sec = 0
    accuracy_groups = {0:0, 1:0, 2:0, 3:0}
    all_assessments = []
    accumulated_accuracy_group = 0
    accumulated_accuracy = 0
    accumulated_correct_attempts = 0 
    accumulated_uncorrect_attempts = 0
    accumulated_actions = 0
    counter = 0
    time_first_activity = float(user_sample['timestamp'].values[0])
    durations = []
    last_accuracy_title = {'acc_' + title: -1 for title in assess_titles}
    event_code_count: Dict[str, int] = {ev: 0 for ev in list_of_event_code}
    event_id_count: Dict[str, int] = {eve: 0 for eve in list_of_event_id}
    title_count: Dict[str, int] = {eve: 0 for eve in activities_labels.values()} 
    title_event_code_count: Dict[str, int] = {t_eve: 0 for t_eve in all_title_event_code}
        
    # last features
    sessions_count = 0
    
    # itarates through each session of one instalation_id
    for i, session in user_sample.groupby('game_session', sort=False):
        # i = game_session_id
        # session is a DataFrame that contain only one game_session
        
        # get some sessions information
        session_type = session['type'].iloc[0]
        session_title = session['title'].iloc[0]
        session_title_text = activities_labels[session_title]
                    
            
        # for each assessment, and only this kind off session, the features below are processed
        # and a register are generated
        if (session_type == 'Assessment') & (test_set or len(session)>1):
            # search for event_code 4100, that represents the assessments trial
            all_attempts = session.query(f'event_code == {win_code[session_title]}')
            # then, check the numbers of wins and the number of losses
            true_attempts = all_attempts['event_data'].str.contains('true').sum()
            false_attempts = all_attempts['event_data'].str.contains('false').sum()
            # copy a dict to use as feature template, it's initialized with some itens: 
            # {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
            features = user_activities_count.copy()
            features.update(last_accuracy_title.copy())
            features.update(event_code_count.copy())
            features.update(event_id_count.copy())
            features.update(title_count.copy())
            features.update(title_event_code_count.copy())
            features.update(last_accuracy_title.copy())
            features['installation_session_count'] = sessions_count
            
            variety_features = [('var_event_code', event_code_count),
                              ('var_event_id', event_id_count),
                               ('var_title', title_count),
                               ('var_title_event_code', title_event_code_count)]
            
            for name, dict_counts in variety_features:
                arr = np.array(list(dict_counts.values()))
                features[name] = np.count_nonzero(arr)
                 
            # get installation_id for aggregated features
            features['installation_id'] = session['installation_id'].iloc[-1]
            # add title as feature, remembering that title represents the name of the game
            features['session_title'] = session['title'].iloc[0]
            # the 4 lines below add the feature of the history of the trials of this player
            # this is based on the all time attempts so far, at the moment of this assessment
            features['accumulated_correct_attempts'] = accumulated_correct_attempts
            features['accumulated_uncorrect_attempts'] = accumulated_uncorrect_attempts
            accumulated_correct_attempts += true_attempts 
            accumulated_uncorrect_attempts += false_attempts
            # the time spent in the app so far
            if durations == []:
                features['duration_mean'] = 0
                features['duration_std'] = 0
            else:
                features['duration_mean'] = np.mean(durations)
                features['duration_std'] = np.std(durations)
            durations.append((session.iloc[-1, 2] - session.iloc[0, 2] ).seconds)
            # the accurace is the all time wins divided by the all time attempts
            features['accumulated_accuracy'] = accumulated_accuracy/counter if counter > 0 else 0
            accuracy = true_attempts/(true_attempts+false_attempts) if (true_attempts+false_attempts) != 0 else 0
            accumulated_accuracy += accuracy
            last_accuracy_title['acc_' + session_title_text] = accuracy
            # a feature of the current accuracy categorized
            # it is a counter of how many times this player was in each accuracy group
            if accuracy == 0:
                features['accuracy_group'] = 0
            elif accuracy == 1:
                features['accuracy_group'] = 3
            elif accuracy == 0.5:
                features['accuracy_group'] = 2
            else:
                features['accuracy_group'] = 1
            features.update(accuracy_groups)
            accuracy_groups[features['accuracy_group']] += 1
            # mean of the all accuracy groups of this player
            features['accumulated_accuracy_group'] = accumulated_accuracy_group/counter if counter > 0 else 0
            accumulated_accuracy_group += features['accuracy_group']
            # how many actions the player has done so far, it is initialized as 0 and updated some lines below
            features['accumulated_actions'] = accumulated_actions
            
            # there are some conditions to allow this features to be inserted in the datasets
            # if it's a test set, all sessions belong to the final dataset
            # it it's a train, needs to be passed throught this clausule: session.query(f'event_code == {win_code[session_title]}')
            # that means, must exist an event_code 4100 or 4110
            if test_set:
                all_assessments.append(features)
            elif true_attempts+false_attempts > 0:
                all_assessments.append(features)
                
            counter += 1
        
        sessions_count += 1
        # this piece counts how many actions was made in each event_code so far
        def update_counters(counter: dict, col: str):
                num_of_session_count = Counter(session[col])
                for k in num_of_session_count.keys():
                    x = k
                    if col == 'title':
                        x = activities_labels[k]
                    counter[x] += num_of_session_count[k]
                return counter
            
        event_code_count = update_counters(event_code_count, "event_code")
        event_id_count = update_counters(event_id_count, "event_id")
        title_count = update_counters(title_count, 'title')
        title_event_code_count = update_counters(title_event_code_count, 'title_event_code')

        # counts how many actions the player has done so far, used in the feature of the same name
        accumulated_actions += len(session)
        if last_activity != session_type:
            user_activities_count[session_type] += 1
            last_activitiy = session_type 
                        
    # if it't the test_set, only the last assessment must be predicted, the previous are scraped
    if test_set:
        return all_assessments[-1]
    # in the train_set, all assessments goes to the dataset
    return all_assessments

# %%
def get_train_and_test(train, test):
    compiled_train = []
    compiled_test = []
    for i, (ins_id, user_sample) in tqdm(enumerate(train.groupby('installation_id', sort = False)), total = 17000):
        compiled_train += get_data(user_sample)
    for ins_id, user_sample in tqdm(test.groupby('installation_id', sort = False), total = 1000):
        test_data = get_data(user_sample, test_set = True)
        compiled_test.append(test_data)
    reduce_train = pd.DataFrame(compiled_train)
    reduce_test = pd.DataFrame(compiled_test)
    categoricals = ['session_title']
    return reduce_train, reduce_test, categoricals

# %%
class Base_Model(object):
    
    def __init__(self, train_df, test_df, features, categoricals=[], n_splits=5, verbose=True):
        self.train_df = train_df
        self.test_df = test_df
        self.features = features
        self.n_splits = n_splits
        self.categoricals = categoricals
        self.target = 'accuracy_group'
        self.cv = self.get_cv()
        self.verbose = verbose
        self.params = self.get_params()
        self.y_pred, self.score, self.model = self.fit()
        
    def train_model(self, train_set, val_set):
        raise NotImplementedError
        
    def get_cv(self):
        cv = StratifiedKFold(n_splits=self.n_splits, shuffle=True, random_state=42)
        return cv.split(self.train_df, self.train_df[self.target])
    
    def get_params(self):
        raise NotImplementedError
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        raise NotImplementedError
        
    def convert_x(self, x):
        return x
        
    def fit(self):
        oof_pred = np.zeros((len(reduce_train), ))
        y_pred = np.zeros((len(reduce_test), ))
        for fold, (train_idx, val_idx) in enumerate(self.cv):
            x_train, x_val = self.train_df[self.features].iloc[train_idx], self.train_df[self.features].iloc[val_idx]
            y_train, y_val = self.train_df[self.target][train_idx], self.train_df[self.target][val_idx]
            train_set, val_set = self.convert_dataset(x_train, y_train, x_val, y_val)
            model = self.train_model(train_set, val_set)
            conv_x_val = self.convert_x(x_val)
            oof_pred[val_idx] = model.predict(conv_x_val).reshape(oof_pred[val_idx].shape)
            x_test = self.convert_x(self.test_df[self.features])
            y_pred += model.predict(x_test).reshape(y_pred.shape) / self.n_splits
            print('Partial score of fold {} is: {}'.format(fold, eval_qwk_lgb_regr(y_val, oof_pred[val_idx])[1]))
        _, loss_score, _ = eval_qwk_lgb_regr(self.train_df[self.target], oof_pred)
        if self.verbose:
            print('Our oof cohen kappa score is: ', loss_score)
        return y_pred, loss_score, model

# %%
class Lgb_Model(Base_Model):
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return lgb.train(self.params, train_set, valid_sets=[train_set, val_set], verbose_eval=verbosity)
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = lgb.Dataset(x_train, y_train, categorical_feature=self.categoricals)
        val_set = lgb.Dataset(x_val, y_val, categorical_feature=self.categoricals)
        return train_set, val_set
        
    def get_params(self):
        params = {'n_estimators':5000,
                    'boosting_type': 'gbdt',
                    'objective': 'regression',
                    'metric': 'rmse',
                    'subsample': 0.75,
                    'subsample_freq': 1,
                    'learning_rate': 0.01,
                    'feature_fraction': 0.9,
                    'max_depth': 15,
                    'lambda_l1': 1,  
                    'lambda_l2': 1,
                    'early_stopping_rounds': 100
                    }
        return params

# %%
class Xgb_Model(Base_Model):
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return xgb.train(self.params, train_set, 
                         num_boost_round=5000, evals=[(train_set, 'train'), (val_set, 'val')], 
                         verbose_eval=verbosity, early_stopping_rounds=100)
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = xgb.DMatrix(x_train, y_train)
        val_set = xgb.DMatrix(x_val, y_val)
        return train_set, val_set
    
    def convert_x(self, x):
        return xgb.DMatrix(x)
        
    def get_params(self):
        params = {'colsample_bytree': 0.8,                 
            'learning_rate': 0.01,
            'max_depth': 10,
            'subsample': 1,
            'objective':'reg:squarederror',
            #'eval_metric':'rmse',
            'min_child_weight':3,
            'gamma':0.25,
            'n_estimators':5000}

        return params

# %%
class Catb_Model(Base_Model):
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        clf = CatBoostRegressor(**self.params)
        clf.fit(train_set['X'], 
                train_set['y'], 
                eval_set=(val_set['X'], val_set['y']),
                verbose=verbosity, 
                cat_features=self.categoricals)
        return clf
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = {'X': x_train, 'y': y_train}
        val_set = {'X': x_val, 'y': y_val}
        return train_set, val_set
        
    def get_params(self):
        params = {'loss_function': 'RMSE',
                   'task_type': "CPU",
                   'iterations': 5000,
                   'od_type': "Iter",
                    'depth': 10,
                  'colsample_bylevel': 0.5, 
                   'early_stopping_rounds': 300,
                    'l2_leaf_reg': 18,
                   'random_seed': 42,
                    'use_best_model': True
                    }
        return params

# %%
import tensorflow as tf
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder

class Nn_Model(Base_Model):
    
    def __init__(self, train_df, test_df, features, categoricals=[], n_splits=5, verbose=True):
        features = features.copy()
        if len(categoricals) > 0:
            for cat in categoricals:
                enc = OneHotEncoder()
                train_cats = enc.fit_transform(train_df[[cat]])
                test_cats = enc.transform(test_df[[cat]])
                cat_cols = ['{}_{}'.format(cat, str(col)) for col in enc.active_features_]
                features += cat_cols
                train_cats = pd.DataFrame(train_cats.toarray(), columns=cat_cols)
                test_cats = pd.DataFrame(test_cats.toarray(), columns=cat_cols)
                train_df = pd.concat([train_df, train_cats], axis=1)
                test_df = pd.concat([test_df, test_cats], axis=1)
        scalar = MinMaxScaler()
        train_df[features] = scalar.fit_transform(train_df[features])
        test_df[features] = scalar.transform(test_df[features])
        print(train_df[features].shape)
        super().__init__(train_df, test_df, features, categoricals, n_splits, verbose)
        
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        model = tf.keras.models.Sequential([
            tf.keras.layers.Input(shape=(train_set['X'].shape[1],)),
            tf.keras.layers.Dense(200, activation='relu'),
            tf.keras.layers.LayerNormalization(),
            tf.keras.layers.Dropout(0.3),
            tf.keras.layers.Dense(100, activation='relu'),
            tf.keras.layers.LayerNormalization(),
            tf.keras.layers.Dropout(0.3),
            tf.keras.layers.Dense(50, activation='relu'),
            tf.keras.layers.LayerNormalization(),
            tf.keras.layers.Dropout(0.3),
            tf.keras.layers.Dense(25, activation='relu'),
            tf.keras.layers.LayerNormalization(),
            tf.keras.layers.Dropout(0.3),
            tf.keras.layers.Dense(1, activation='relu')
        ])
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=4e-4), loss='mse')
        print(model.summary())
        save_best = tf.keras.callbacks.ModelCheckpoint('nn_model.w8', save_weights_only=True, save_best_only=True, verbose=1)
        early_stop = tf.keras.callbacks.EarlyStopping(patience=20)
        model.fit(train_set['X'], 
                train_set['y'], 
                validation_data=(val_set['X'], val_set['y']),
                epochs=100,
                 callbacks=[save_best, early_stop])
        model.load_weights('nn_model.w8')
        return model
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = {'X': x_train, 'y': y_train}
        val_set = {'X': x_val, 'y': y_val}
        return train_set, val_set
        
    def get_params(self):
        return None

# %%
from random import choice

class Cnn_Model(Base_Model):
    
    def __init__(self, train_df, test_df, features, categoricals=[], n_splits=5, verbose=True):
        features = features.copy()
        if len(categoricals) > 0:
            for cat in categoricals:
                enc = OneHotEncoder()
                train_cats = enc.fit_transform(train_df[[cat]])
                test_cats = enc.transform(test_df[[cat]])
                cat_cols = ['{}_{}'.format(cat, str(col)) for col in enc.active_features_]
                features += cat_cols
                train_cats = pd.DataFrame(train_cats.toarray(), columns=cat_cols)
                test_cats = pd.DataFrame(test_cats.toarray(), columns=cat_cols)
                train_df = pd.concat([train_df, train_cats], axis=1)
                test_df = pd.concat([test_df, test_cats], axis=1)
        scalar = MinMaxScaler()
        train_df[features] = scalar.fit_transform(train_df[features])
        test_df[features] = scalar.transform(test_df[features])
        self.create_feat_2d(features)
        super().__init__(train_df, test_df, features, categoricals, n_splits, verbose)
        
    def create_feat_2d(self, features, n_feats_repeat=50):
        self.n_feats = len(features)
        self.n_feats_repeat = n_feats_repeat
        self.mask = np.zeros((self.n_feats_repeat, self.n_feats), dtype=np.int32)
        for i in range(self.n_feats_repeat):
            l = list(range(self.n_feats))
            for j in range(self.n_feats):
                c = l.pop(choice(range(len(l))))
                self.mask[i, j] = c
        self.mask = tf.convert_to_tensor(self.mask)
        print(self.mask.shape)
       
        
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0

        inp = tf.keras.layers.Input(shape=(self.n_feats))
        x = tf.keras.layers.Lambda(lambda x: tf.gather(x, self.mask, axis=1))(inp)
        x = tf.keras.layers.Reshape((self.n_feats_repeat, self.n_feats, 1))(x)
        x = tf.keras.layers.Conv2D(18, (50, 50), strides=50, activation='relu')(x)
        x = tf.keras.layers.Flatten()(x)
        #x = tf.keras.layers.Dense(200, activation='relu')(x)
        #x = tf.keras.layers.LayerNormalization()(x)
        #x = tf.keras.layers.Dropout(0.3)(x)
        x = tf.keras.layers.Dense(100, activation='relu')(x)
        x = tf.keras.layers.LayerNormalization()(x)
        x = tf.keras.layers.Dropout(0.3)(x)
        x = tf.keras.layers.Dense(50, activation='relu')(x)
        x = tf.keras.layers.LayerNormalization()(x)
        x = tf.keras.layers.Dropout(0.3)(x)
        out = tf.keras.layers.Dense(1)(x)
        
        model = tf.keras.Model(inp, out)
    
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='mse')
        print(model.summary())
        save_best = tf.keras.callbacks.ModelCheckpoint('nn_model.w8', save_weights_only=True, save_best_only=True, verbose=1)
        early_stop = tf.keras.callbacks.EarlyStopping(patience=20)
        model.fit(train_set['X'], 
                train_set['y'], 
                validation_data=(val_set['X'], val_set['y']),
                epochs=100,
                 callbacks=[save_best, early_stop])
        model.load_weights('nn_model.w8')
        return model
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = {'X': x_train, 'y': y_train}
        val_set = {'X': x_val, 'y': y_val}
        return train_set, val_set
        
    def get_params(self):
        return None

# %%
# read data
train, test, train_labels, specs, sample_submission = read_data()
# get usefull dict with maping encode
train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, activities_labels, assess_titles, list_of_event_id, all_title_event_code = encode_title(train, test, train_labels)
# tranform function to get the train and test set
reduce_train, reduce_test, categoricals = get_train_and_test(train, test)
# Out:
# Reading train.csv file....
# Training.csv file have 11341042 rows and 11 columns
# Reading test.csv file....
# Test.csv file have 1156414 rows and 11 columns
# Reading train_labels.csv file....
# Train_labels.csv file have 17690 rows and 7 columns
# Reading specs.csv file....
# Specs.csv file have 386 rows and 3 columns
# Reading sample_submission.csv file....
# Sample_submission.csv file have 1000 rows and 2 columns
# HBox(children=(IntProgress(value=0, max=17000), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
def stract_hists(feature, train=reduce_train, test=reduce_test, adjust=False, plot=False):
    n_bins = 10
    train_data = train[feature]
    test_data = test[feature]
    if adjust:
        test_data *= train_data.mean() / test_data.mean()
    perc_90 = np.percentile(train_data, 95)
    train_data = np.clip(train_data, 0, perc_90)
    test_data = np.clip(test_data, 0, perc_90)
    train_hist = np.histogram(train_data, bins=n_bins)[0] / len(train_data)
    test_hist = np.histogram(test_data, bins=n_bins)[0] / len(test_data)
    msre = mean_squared_error(train_hist, test_hist)
    if plot:
        print(msre)
        plt.bar(range(n_bins), train_hist, color='blue', alpha=0.5)
        plt.bar(range(n_bins), test_hist, color='red', alpha=0.5)
        plt.show()
    return msre
stract_hists('Magma Peak - Level 1_2000', adjust=False, plot=True)
# Out:
# 0.0026939774600629332
# 0.0026939774600629332

# %%
# call feature engineering function
features = reduce_train.loc[(reduce_train.sum(axis=1) != 0), (reduce_train.sum(axis=0) != 0)].columns # delete useless columns
features = [x for x in features if x not in ['accuracy_group', 'installation_id']]

# %%
counter = 0
to_remove = []
for feat_a in features:
    for feat_b in features:
        if feat_a != feat_b and feat_a not in to_remove and feat_b not in to_remove:
            c = np.corrcoef(reduce_train[feat_a], reduce_train[feat_b])[0][1]
            if c > 0.995:
                counter += 1
                to_remove.append(feat_b)
                print('{}: FEAT_A: {} FEAT_B: {} - Correlation: {}'.format(counter, feat_a, feat_b, c))
# Out:
# 1: FEAT_A: Clip FEAT_B: 27253bdc - Correlation: 1.0
# 2: FEAT_A: 2050 FEAT_B: 2040 - Correlation: 0.9965259434878119
# 3: FEAT_A: 2050 FEAT_B: 26fd2d99 - Correlation: 0.9965084543995756
# 4: FEAT_A: 2050 FEAT_B: 37c53127 - Correlation: 0.9999999999999998
# 5: FEAT_A: 2050 FEAT_B: dcaede90 - Correlation: 0.9965259434878119
# 6: FEAT_A: 2050 FEAT_B: 08fd73f3 - Correlation: 0.9966123918733647
# 7: FEAT_A: 2050 FEAT_B: 73757a5e - Correlation: 0.9998050146713994
# 8: FEAT_A: 2050 FEAT_B: 2b9272f4 - Correlation: 0.9999839030068788
# 9: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_2020 - Correlation: 0.9965084543995756
# 10: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_3021 - Correlation: 0.9998050146713994
# 11: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_3121 - Correlation: 0.9999839030068788
# 12: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_2030 - Correlation: 0.9966123918733647
# 13: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_2050 - Correlation: 0.9999999999999998
# 14: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_2040 - Correlation: 0.9965259434878119
# 15: FEAT_A: 4230 FEAT_B: 4235 - Correlation: 0.9999995197498742
# 16: FEAT_A: 4230 FEAT_B: 85de926c - Correlation: 0.9999995197498742
# 17: FEAT_A: 4230 FEAT_B: ad148f58 - Correlation: 0.9999999999999998
# 18: FEAT_A: 4230 FEAT_B: Bubble Bath_4230 - Correlation: 0.9999999999999998
# 19: FEAT_A: 4230 FEAT_B: Bubble Bath_4235 - Correlation: 0.9999995197498742
# 20: FEAT_A: 5000 FEAT_B: 5010 - Correlation: 0.9991849213605325
# 21: FEAT_A: 5000 FEAT_B: 71e712d8 - Correlation: 0.9991849213605325
# 22: FEAT_A: 5000 FEAT_B: a6d66e51 - Correlation: 1.0
# 23: FEAT_A: 5000 FEAT_B: Watering Hole (Activity)_5010 - Correlation: 0.9991849213605325
# 24: FEAT_A: 5000 FEAT_B: Watering Hole (Activity)_5000 - Correlation: 1.0
# 25: FEAT_A: 3110 FEAT_B: 3010 - Correlation: 0.9999293402893734
# 26: FEAT_A: 3120 FEAT_B: 3020 - Correlation: 0.9998761417908977
# 27: FEAT_A: 3121 FEAT_B: 3021 - Correlation: 0.9999098200487938
# 28: FEAT_A: 4031 FEAT_B: 1996c610 - Correlation: 1.0
# 29: FEAT_A: 4031 FEAT_B: Dino Drink_4031 - Correlation: 1.0
# 30: FEAT_A: 2000 FEAT_B: installation_session_count - Correlation: 1.0
# 31: FEAT_A: 4050 FEAT_B: a1192f43 - Correlation: 1.0
# 32: FEAT_A: 4050 FEAT_B: Crystals Rule_4050 - Correlation: 1.0
# 33: FEAT_A: 2020 FEAT_B: 2030 - Correlation: 0.9959933262816538
# 34: FEAT_A: 4220 FEAT_B: 1340b8d7 - Correlation: 1.0
# 35: FEAT_A: 4220 FEAT_B: Bubble Bath_4220 - Correlation: 1.0
# 36: FEAT_A: 33505eae FEAT_B: 2a512369 - Correlation: 0.9994585292841968
# 37: FEAT_A: 33505eae FEAT_B: Leaf Leader_3010 - Correlation: 1.0
# 38: FEAT_A: 33505eae FEAT_B: Leaf Leader_3110 - Correlation: 0.9994585292841968
# 39: FEAT_A: cdd22e43 FEAT_B: Chicken Balancer (Activity)_4035 - Correlation: 1.0
# 40: FEAT_A: c189aaf2 FEAT_B: Happy Camel_2083 - Correlation: 1.0
# 41: FEAT_A: e64e2cfd FEAT_B: Watering Hole (Activity)_2000 - Correlation: 1.0
# 42: FEAT_A: c74f40cd FEAT_B: 28ed704e - Correlation: 0.9955185671057014
# 43: FEAT_A: c74f40cd FEAT_B: 3dfd4aa4 - Correlation: 0.9963968989064971
# 44: FEAT_A: c74f40cd FEAT_B: 9d29771f - Correlation: 0.9999553655332966
# 45: FEAT_A: c74f40cd FEAT_B: 83c6c409 - Correlation: 0.9963987221516334
# 46: FEAT_A: c74f40cd FEAT_B: Mushroom Sorter (Assessment)_4025 - Correlation: 0.9955185671057014
# 47: FEAT_A: c74f40cd FEAT_B: Mushroom Sorter (Assessment)_2020 - Correlation: 0.9963968989064971
# 48: FEAT_A: c74f40cd FEAT_B: Mushroom Sorter (Assessment)_2035 - Correlation: 0.9963987221516334
# 49: FEAT_A: c74f40cd FEAT_B: Mushroom Sorter (Assessment)_3021 - Correlation: 0.9999553655332966
# 50: FEAT_A: c74f40cd FEAT_B: Mushroom Sorter (Assessment)_3121 - Correlation: 1.0
# 51: FEAT_A: 6cf7d25c FEAT_B: 15f99afc - Correlation: 0.9994848234397951
# 52: FEAT_A: 6cf7d25c FEAT_B: Pan Balance_3010 - Correlation: 1.0
# 53: FEAT_A: 6cf7d25c FEAT_B: Pan Balance_3110 - Correlation: 0.9994848234397951
# 54: FEAT_A: 756e5507 FEAT_B: Chicken Balancer (Activity)_2000 - Correlation: 1.0
# 55: FEAT_A: 2dc29e21 FEAT_B: All Star Sorting_4020 - Correlation: 1.0
# 56: FEAT_A: f806dc10 FEAT_B: Dino Drink_2020 - Correlation: 1.0
# 57: FEAT_A: 6bf9e3e1 FEAT_B: Happy Camel_4040 - Correlation: 0.9999999999999999
# 58: FEAT_A: 8d7e386c FEAT_B: 69fdac0a - Correlation: 0.9996590210382708
# 59: FEAT_A: 8d7e386c FEAT_B: Happy Camel_3110 - Correlation: 0.9996590210382708
# 60: FEAT_A: 8d7e386c FEAT_B: Happy Camel_3010 - Correlation: 0.9999999999999999
# 61: FEAT_A: e4f1efe6 FEAT_B: 3afb49e6 - Correlation: 0.9985179906980803
# 62: FEAT_A: e4f1efe6 FEAT_B: 38074c54 - Correlation: 0.9984044689083411
# 63: FEAT_A: e4f1efe6 FEAT_B: 222660ff - Correlation: 0.9984044689083411
# 64: FEAT_A: e4f1efe6 FEAT_B: Chest Sorter (Assessment)_2030 - Correlation: 0.9984044689083411
# 65: FEAT_A: e4f1efe6 FEAT_B: Chest Sorter (Assessment)_3121 - Correlation: 0.9999999999999998
# 66: FEAT_A: e4f1efe6 FEAT_B: Chest Sorter (Assessment)_3021 - Correlation: 0.9985179906980803
# 67: FEAT_A: e4f1efe6 FEAT_B: Chest Sorter (Assessment)_2010 - Correlation: 0.9984044689083411
# 68: FEAT_A: 1cc7cfca FEAT_B: All Star Sorting_4030 - Correlation: 1.0
# 69: FEAT_A: bb3e370b FEAT_B: Bottle Filler (Activity) - Correlation: 0.9950043311420309
# 70: FEAT_A: bb3e370b FEAT_B: Bottle Filler (Activity)_4030 - Correlation: 0.9999999999999999
# 71: FEAT_A: 9ce586dd FEAT_B: Chest Sorter (Assessment)_4035 - Correlation: 1.0
# 72: FEAT_A: d9c005dd FEAT_B: Happy Camel_2000 - Correlation: 1.0
# 73: FEAT_A: b7530680 FEAT_B: e9c52111 - Correlation: 0.9988176899646234
# 74: FEAT_A: b7530680 FEAT_B: Bottle Filler (Activity)_2020 - Correlation: 1.0
# 75: FEAT_A: b7530680 FEAT_B: Bottle Filler (Activity)_2030 - Correlation: 0.9988176899646234
# 76: FEAT_A: 7f0836bf FEAT_B: a29c5338 - Correlation: 0.9986531654717631
# 77: FEAT_A: 7f0836bf FEAT_B: Dino Drink_3110 - Correlation: 0.9999999999999999
# 78: FEAT_A: 7f0836bf FEAT_B: Dino Drink_3010 - Correlation: 0.9986531654717631
# 79: FEAT_A: 77261ab5 FEAT_B: Sandcastle Builder (Activity)_2000 - Correlation: 0.9999999999999999
# 80: FEAT_A: 363c86c9 FEAT_B: Bug Measurer (Activity)_4035 - Correlation: 0.9999999999999998
# 81: FEAT_A: 9e6b7fb5 FEAT_B: Chow Time_4095 - Correlation: 0.9999999999999998
# 82: FEAT_A: 6077cc36 FEAT_B: Bird Measurer (Assessment)_4080 - Correlation: 1.0
# 83: FEAT_A: ca11f653 FEAT_B: 1f19558b - Correlation: 0.9983164273410822
# 84: FEAT_A: ca11f653 FEAT_B: daac11b0 - Correlation: 0.9995251307611358
# 85: FEAT_A: ca11f653 FEAT_B: All Star Sorting_3021 - Correlation: 0.9995251307611358
# 86: FEAT_A: ca11f653 FEAT_B: All Star Sorting_3121 - Correlation: 0.9983164273410822
# 87: FEAT_A: ca11f653 FEAT_B: All Star Sorting_2030 - Correlation: 1.0
# 88: FEAT_A: 5c3d2b2f FEAT_B: Scrub-A-Dub_4020 - Correlation: 1.0
# 89: FEAT_A: 13f56524 FEAT_B: Mushroom Sorter (Assessment)_4080 - Correlation: 1.0
# 90: FEAT_A: 4bb2f698 FEAT_B: Chicken Balancer (Activity)_4070 - Correlation: 1.0
# 91: FEAT_A: d02b7a8e FEAT_B: All Star Sorting_4035 - Correlation: 1.0
# 92: FEAT_A: 37ee8496 FEAT_B: 30614231 - Correlation: 0.9967763987631837
# 93: FEAT_A: 37ee8496 FEAT_B: Cauldron Filler (Assessment)_4030 - Correlation: 1.0
# 94: FEAT_A: 37ee8496 FEAT_B: Cauldron Filler (Assessment)_4020 - Correlation: 0.9967763987631837
# 95: FEAT_A: 53c6e11a FEAT_B: Leaf Leader_2075 - Correlation: 1.0
# 96: FEAT_A: 2c4e6db0 FEAT_B: All Star Sorting_2020 - Correlation: 1.0
# 97: FEAT_A: 05ad839b FEAT_B: Happy Camel_4090 - Correlation: 0.9999999999999999
# 98: FEAT_A: fbaf3456 FEAT_B: Mushroom Sorter (Assessment)_4030 - Correlation: 0.9999999999999999
# 99: FEAT_A: 47f43a44 FEAT_B: Flower Waterer (Activity)_4090 - Correlation: 0.9999999999999999
# 100: FEAT_A: e5734469 FEAT_B: 89aace00 - Correlation: 0.9998406115110344
# 101: FEAT_A: e5734469 FEAT_B: Dino Drink_3120 - Correlation: 0.9998406115110344
# 102: FEAT_A: e5734469 FEAT_B: Dino Drink_3020 - Correlation: 1.0
# 103: FEAT_A: 77c76bc5 FEAT_B: Cauldron Filler (Assessment)_4090 - Correlation: 1.0
# 104: FEAT_A: a76029ee FEAT_B: Bird Measurer (Assessment)_4040 - Correlation: 1.0
# 105: FEAT_A: a7640a16 FEAT_B: Happy Camel_4070 - Correlation: 0.9999999999999999
# 106: FEAT_A: 17113b36 FEAT_B: ad2fc29c - Correlation: 0.9988424704659319
# 107: FEAT_A: 17113b36 FEAT_B: e37a2b78 - Correlation: 0.9982548122198933
# 108: FEAT_A: 17113b36 FEAT_B: Bird Measurer (Assessment)_4110 - Correlation: 1.0
# 109: FEAT_A: 17113b36 FEAT_B: Bird Measurer (Assessment)_3120 - Correlation: 0.9982548122198933
# 110: FEAT_A: 17113b36 FEAT_B: Bird Measurer (Assessment)_3020 - Correlation: 0.9988424704659319
# 111: FEAT_A: c7fe2a55 FEAT_B: a8a78786 - Correlation: 0.998145203935079
# 112: FEAT_A: c7fe2a55 FEAT_B: 36fa3ebe - Correlation: 0.9998350234117687
# 113: FEAT_A: c7fe2a55 FEAT_B: Happy Camel_2030 - Correlation: 0.9998350234117687
# 114: FEAT_A: c7fe2a55 FEAT_B: Happy Camel_3021 - Correlation: 1.0
# 115: FEAT_A: c7fe2a55 FEAT_B: Happy Camel_3121 - Correlation: 0.998145203935079
# 116: FEAT_A: f5b8c21a FEAT_B: 58a0de5c - Correlation: 0.9977888184537717
# 117: FEAT_A: f5b8c21a FEAT_B: 9b4001e4 - Correlation: 0.9976837802056775
# 118: FEAT_A: f5b8c21a FEAT_B: Air Show_2030 - Correlation: 1.0
# 119: FEAT_A: f5b8c21a FEAT_B: Air Show_3021 - Correlation: 0.9976837802056775
# 120: FEAT_A: f5b8c21a FEAT_B: Air Show_3121 - Correlation: 0.9977888184537717
# 121: FEAT_A: 1cf54632 FEAT_B: Bubble Bath_2000 - Correlation: 0.9999999999999999
# 122: FEAT_A: e5c9df6f FEAT_B: 3afde5dd - Correlation: 0.9990910601838003
# 123: FEAT_A: e5c9df6f FEAT_B: b012cd7f - Correlation: 0.9990885395773583
# 124: FEAT_A: e5c9df6f FEAT_B: Leaf Leader_3121 - Correlation: 0.9999999999999999
# 125: FEAT_A: e5c9df6f FEAT_B: Leaf Leader_2030 - Correlation: 0.9990885395773583
# 126: FEAT_A: e5c9df6f FEAT_B: Leaf Leader_3021 - Correlation: 0.9990910601838003
# 127: FEAT_A: e57dd7af FEAT_B: 763fc34e - Correlation: 0.9972721980394432
# 128: FEAT_A: e57dd7af FEAT_B: Leaf Leader_3120 - Correlation: 0.9999999999999999
# 129: FEAT_A: e57dd7af FEAT_B: Leaf Leader_3020 - Correlation: 0.9972721980394432
# 130: FEAT_A: 7372e1a5 FEAT_B: Chow Time_4070 - Correlation: 0.9999999999999999
# 131: FEAT_A: 3a4be871 FEAT_B: Flower Waterer (Activity)_4080 - Correlation: 1.0
# 132: FEAT_A: d88ca108 FEAT_B: Air Show_2070 - Correlation: 0.9999999999999998
# 133: FEAT_A: bc8f2793 FEAT_B: Pan Balance_4035 - Correlation: 1.0
# 134: FEAT_A: 29bdd9ba FEAT_B: Dino Dive_2000 - Correlation: 1.0
# 135: FEAT_A: d3268efa FEAT_B: 28520915 - Correlation: 0.9989055023166139
# 136: FEAT_A: d3268efa FEAT_B: b5053438 - Correlation: 0.9995763267046308
# 137: FEAT_A: d3268efa FEAT_B: Cauldron Filler (Assessment)_3121 - Correlation: 0.9995763267046308
# 138: FEAT_A: d3268efa FEAT_B: Cauldron Filler (Assessment)_2030 - Correlation: 0.9989055023166139
# 139: FEAT_A: d3268efa FEAT_B: Cauldron Filler (Assessment)_3021 - Correlation: 0.9999999999999998
# 140: FEAT_A: 3bfd1a65 FEAT_B: db02c830 - Correlation: 0.9999982205265874
# 141: FEAT_A: 3bfd1a65 FEAT_B: Mushroom Sorter (Assessment)_2025 - Correlation: 0.9999982205265874
# 142: FEAT_A: 3bfd1a65 FEAT_B: Mushroom Sorter (Assessment)_2000 - Correlation: 1.0
# 143: FEAT_A: b80e5e84 FEAT_B: 7ab78247 - Correlation: 0.999833659028109
# 144: FEAT_A: b80e5e84 FEAT_B: Egg Dropper (Activity)_3110 - Correlation: 0.9999999999999998
# 145: FEAT_A: b80e5e84 FEAT_B: Egg Dropper (Activity)_3010 - Correlation: 0.999833659028109
# 146: FEAT_A: 49ed92e9 FEAT_B: bd701df8 - Correlation: 0.9993109138888525
# 147: FEAT_A: 49ed92e9 FEAT_B: Watering Hole (Activity)_3010 - Correlation: 1.0
# 148: FEAT_A: 49ed92e9 FEAT_B: Watering Hole (Activity)_3110 - Correlation: 0.9993109138888525
# 149: FEAT_A: 731c0cbe FEAT_B: Bird Measurer (Assessment)_4090 - Correlation: 1.0
# 150: FEAT_A: 6f8106d9 FEAT_B: Dino Drink_4090 - Correlation: 1.0
# 151: FEAT_A: 363d3849 FEAT_B: 9e4c8c7b - Correlation: 0.9992130941883628
# 152: FEAT_A: 363d3849 FEAT_B: All Star Sorting_3110 - Correlation: 0.9992130941883628
# 153: FEAT_A: 363d3849 FEAT_B: All Star Sorting_3010 - Correlation: 1.0
# 154: FEAT_A: 587b5989 FEAT_B: All Star Sorting_4070 - Correlation: 1.0
# 155: FEAT_A: 6f4bd64e FEAT_B: Air Show_4090 - Correlation: 1.0
# 156: FEAT_A: 6043a2b4 FEAT_B: All Star Sorting_4090 - Correlation: 1.0
# 157: FEAT_A: 4a4c3d21 FEAT_B: Bird Measurer (Assessment)_4025 - Correlation: 1.0
# 158: FEAT_A: e7e44842 FEAT_B: Watering Hole (Activity)_4090 - Correlation: 1.0
# 159: FEAT_A: ecc36b7f FEAT_B: Bubble Bath_4095 - Correlation: 0.9999999999999998
# 160: FEAT_A: acf5c23f FEAT_B: Cart Balancer (Assessment)_4070 - Correlation: 1.0
# 161: FEAT_A: 7ec0c298 FEAT_B: Chow Time_3010 - Correlation: 1.0
# 162: FEAT_A: 7fd1ac25 FEAT_B: Egg Dropper (Activity)_4080 - Correlation: 1.0
# 163: FEAT_A: 76babcde FEAT_B: Dino Dive_4070 - Correlation: 0.9999999999999999
# 164: FEAT_A: ac92046e FEAT_B: d88e8f25 - Correlation: 0.999976307033209
# 165: FEAT_A: ac92046e FEAT_B: Scrub-A-Dub_3120 - Correlation: 1.0
# 166: FEAT_A: ac92046e FEAT_B: Scrub-A-Dub_3020 - Correlation: 0.999976307033209
# 167: FEAT_A: 15a43e5b FEAT_B: Bottle Filler (Activity)_4070 - Correlation: 1.0
# 168: FEAT_A: 4a09ace1 FEAT_B: Scrub-A-Dub_2083 - Correlation: 1.0
# 169: FEAT_A: f32856e4 FEAT_B: Leaf Leader_2020 - Correlation: 1.0
# 170: FEAT_A: f71c4741 FEAT_B: f7e47413 - Correlation: 0.999942689077087
# 171: FEAT_A: f71c4741 FEAT_B: Scrub-A-Dub_3010 - Correlation: 0.9999999999999998
# 172: FEAT_A: f71c4741 FEAT_B: Scrub-A-Dub_3110 - Correlation: 0.999942689077087
# 173: FEAT_A: 9e34ea74 FEAT_B: Egg Dropper (Activity)_4070 - Correlation: 1.0
# 174: FEAT_A: 63f13dd7 FEAT_B: Chow Time_2020 - Correlation: 1.0
# 175: FEAT_A: 08ff79ad FEAT_B: Egg Dropper (Activity)_4090 - Correlation: 0.9999999999999999
# 176: FEAT_A: 56bcd38d FEAT_B: Chicken Balancer (Activity)_4030 - Correlation: 1.0
# 177: FEAT_A: 8b757ab8 FEAT_B: 44cb4907 - Correlation: 0.9998350587947098
# 178: FEAT_A: 8b757ab8 FEAT_B: Crystals Rule_3020 - Correlation: 0.9998350587947098
# 179: FEAT_A: 8b757ab8 FEAT_B: Crystals Rule_3120 - Correlation: 1.0
# 180: FEAT_A: 895865f3 FEAT_B: 3bb91dda - Correlation: 0.9962789226264861
# 181: FEAT_A: 895865f3 FEAT_B: c54cf6c5 - Correlation: 0.9964317167511049
# 182: FEAT_A: 895865f3 FEAT_B: d06f75b5 - Correlation: 0.9991496470458575
# 183: FEAT_A: 895865f3 FEAT_B: Bubble Bath_2030 - Correlation: 1.0
# 184: FEAT_A: 895865f3 FEAT_B: Bubble Bath_2035 - Correlation: 0.9991496470458575
# 185: FEAT_A: 895865f3 FEAT_B: Bubble Bath_4020 - Correlation: 0.9962789226264861
# 186: FEAT_A: 895865f3 FEAT_B: Bubble Bath_2025 - Correlation: 0.9964317167511049
# 187: FEAT_A: 7423acbc FEAT_B: e04fb33d - Correlation: 0.9996289974081254
# 188: FEAT_A: 7423acbc FEAT_B: Air Show_3020 - Correlation: 0.9999999999999999
# 189: FEAT_A: 7423acbc FEAT_B: Air Show_3120 - Correlation: 0.9996289974081254
# 190: FEAT_A: c7128948 FEAT_B: Mushroom Sorter (Assessment)_4040 - Correlation: 1.0
# 191: FEAT_A: 28a4eb9a FEAT_B: 9de5e594 - Correlation: 0.9995923561196802
# 192: FEAT_A: 28a4eb9a FEAT_B: Dino Dive_3120 - Correlation: 1.0
# 193: FEAT_A: 28a4eb9a FEAT_B: Dino Dive_3020 - Correlation: 0.9995923561196802
# 194: FEAT_A: 00c73085 FEAT_B: Dino Dive_2030 - Correlation: 1.0
# 195: FEAT_A: bcceccc6 FEAT_B: Air Show_4070 - Correlation: 1.0
# 196: FEAT_A: 4b5efe37 FEAT_B: b7dc8128 - Correlation: 0.9980151285383977
# 197: FEAT_A: 4b5efe37 FEAT_B: All Star Sorting_4010 - Correlation: 1.0
# 198: FEAT_A: 4b5efe37 FEAT_B: All Star Sorting_2000 - Correlation: 0.9980151285383977
# 199: FEAT_A: e7561dd2 FEAT_B: Pan Balance_4025 - Correlation: 0.9999999999999998
# 200: FEAT_A: 30df3273 FEAT_B: Sandcastle Builder (Activity)_4080 - Correlation: 0.9999999999999999
# 201: FEAT_A: f50fc6c1 FEAT_B: Watering Hole (Activity)_4021 - Correlation: 1.0
# 202: FEAT_A: abc5811c FEAT_B: Happy Camel_4010 - Correlation: 1.0
# 203: FEAT_A: 4901243f FEAT_B: Fireworks (Activity)_2000 - Correlation: 1.0
# 204: FEAT_A: d2659ab4 FEAT_B: Air Show_2075 - Correlation: 1.0
# 205: FEAT_A: 1c178d24 FEAT_B: a592d54e - Correlation: 0.9973125883100834
# 206: FEAT_A: 1c178d24 FEAT_B: cf7638f3 - Correlation: 0.9996196393003267
# 207: FEAT_A: 1c178d24 FEAT_B: 250513af - Correlation: 0.9999803429610498
# 208: FEAT_A: 1c178d24 FEAT_B: Pan Balance_3121 - Correlation: 0.9996196393003267
# 209: FEAT_A: 1c178d24 FEAT_B: Pan Balance_2030 - Correlation: 1.0
# 210: FEAT_A: 1c178d24 FEAT_B: Pan Balance_3021 - Correlation: 0.9999803429610498
# 211: FEAT_A: 1c178d24 FEAT_B: Pan Balance_2020 - Correlation: 0.9973125883100834
# 212: FEAT_A: 99abe2bb FEAT_B: Bubble Bath_2080 - Correlation: 1.0
# 213: FEAT_A: 9ed8f6da FEAT_B: Dino Drink_2075 - Correlation: 0.9999999999999999
# 214: FEAT_A: c6971acf FEAT_B: Dino Drink_2060 - Correlation: 1.0
# 215: FEAT_A: 47026d5f FEAT_B: cb6010f8 - Correlation: 0.9996901555713468
# 216: FEAT_A: 47026d5f FEAT_B: 56817e2b - Correlation: 0.9993683693704362
# 217: FEAT_A: 47026d5f FEAT_B: Chow Time_3021 - Correlation: 1.0
# 218: FEAT_A: 47026d5f FEAT_B: Chow Time_2030 - Correlation: 0.9993683693704362
# 219: FEAT_A: 47026d5f FEAT_B: Chow Time_3121 - Correlation: 0.9996901555713468
# 220: FEAT_A: 562cec5f FEAT_B: Chest Sorter (Assessment)_4025 - Correlation: 1.0
# 221: FEAT_A: 8fee50e2 FEAT_B: Bird Measurer (Assessment)_4020 - Correlation: 1.0
# 222: FEAT_A: 155f62a4 FEAT_B: 5b49460a - Correlation: 1.0
# 223: FEAT_A: 155f62a4 FEAT_B: Chest Sorter (Assessment)_2020 - Correlation: 1.0
# 224: FEAT_A: 155f62a4 FEAT_B: Chest Sorter (Assessment)_2000 - Correlation: 1.0
# 225: FEAT_A: f6947f54 FEAT_B: Bird Measurer (Assessment)_2030 - Correlation: 0.9999999999999999
# 226: FEAT_A: 29a42aea FEAT_B: Bubble Bath_4080 - Correlation: 1.0
# 227: FEAT_A: 16667cc5 FEAT_B: Chicken Balancer (Activity)_4080 - Correlation: 1.0
# 228: FEAT_A: ea296733 FEAT_B: df4fe8b6 - Correlation: 0.9972489515829075
# 229: FEAT_A: ea296733 FEAT_B: Chest Sorter (Assessment)_3020 - Correlation: 1.0
# 230: FEAT_A: ea296733 FEAT_B: Chest Sorter (Assessment)_3120 - Correlation: 0.9972489515829075
# 231: FEAT_A: 9d4e7b25 FEAT_B: Cart Balancer (Assessment)_4040 - Correlation: 1.0
# 232: FEAT_A: 598f4598 FEAT_B: Flower Waterer (Activity)_4025 - Correlation: 0.9999999999999998
# 233: FEAT_A: 736f9581 FEAT_B: 9b23e8ee - Correlation: 1.0
# 234: FEAT_A: 736f9581 FEAT_B: Egg Dropper (Activity)_2000 - Correlation: 1.0
# 235: FEAT_A: 736f9581 FEAT_B: Egg Dropper (Activity)_2020 - Correlation: 1.0
# 236: FEAT_A: 5a848010 FEAT_B: Scrub-A-Dub_2080 - Correlation: 0.9999999999999999
# 237: FEAT_A: 29f54413 FEAT_B: Leaf Leader_2060 - Correlation: 1.0
# 238: FEAT_A: c51d8688 FEAT_B: 907a054b - Correlation: 0.9999667370361695
# 239: FEAT_A: c51d8688 FEAT_B: Pan Balance_3120 - Correlation: 1.0
# 240: FEAT_A: c51d8688 FEAT_B: Pan Balance_3020 - Correlation: 0.9999667370361695
# 241: FEAT_A: 48349b14 FEAT_B: Crystals Rule_2000 - Correlation: 1.0
# 242: FEAT_A: 6088b756 FEAT_B: Dino Dive_2070 - Correlation: 1.0
# 243: FEAT_A: 1325467d FEAT_B: Sandcastle Builder (Activity)_4070 - Correlation: 1.0
# 244: FEAT_A: 1575e76c FEAT_B: Air Show_2020 - Correlation: 0.9999999999999999
# 245: FEAT_A: 8f094001 FEAT_B: 1beb320a - Correlation: 0.9980774800878138
# 246: FEAT_A: 8f094001 FEAT_B: Bubble Bath_2020 - Correlation: 0.9980774800878138
# 247: FEAT_A: 8f094001 FEAT_B: Bubble Bath_4045 - Correlation: 1.0
# 248: FEAT_A: 67439901 FEAT_B: df4940d3 - Correlation: 0.9999351626435955
# 249: FEAT_A: 67439901 FEAT_B: Bottle Filler (Activity)_3110 - Correlation: 0.9999351626435955
# 250: FEAT_A: 67439901 FEAT_B: Bottle Filler (Activity)_3010 - Correlation: 0.9999999999999999
# 251: FEAT_A: c277e121 FEAT_B: b120f2ac - Correlation: 0.9999983835744556
# 252: FEAT_A: c277e121 FEAT_B: d45ed6a1 - Correlation: 0.9979692879543328
# 253: FEAT_A: c277e121 FEAT_B: All Star Sorting_3120 - Correlation: 0.9979692879543328
# 254: FEAT_A: c277e121 FEAT_B: All Star Sorting_3020 - Correlation: 1.0
# 255: FEAT_A: c277e121 FEAT_B: All Star Sorting_2025 - Correlation: 0.9999983835744556
# 256: FEAT_A: ec138c1c FEAT_B: Bird Measurer (Assessment)_2020 - Correlation: 1.0
# 257: FEAT_A: 7ad3efc6 FEAT_B: 65a38bf7 - Correlation: 0.999978626569042
# 258: FEAT_A: 7ad3efc6 FEAT_B: Cart Balancer (Assessment)_2000 - Correlation: 1.0
# 259: FEAT_A: 7ad3efc6 FEAT_B: Cart Balancer (Assessment)_2020 - Correlation: 0.999978626569042
# 260: FEAT_A: 31973d56 FEAT_B: 5de79a6a - Correlation: 0.9973945339840685
# 261: FEAT_A: 31973d56 FEAT_B: Cart Balancer (Assessment)_3120 - Correlation: 1.0
# 262: FEAT_A: 31973d56 FEAT_B: Cart Balancer (Assessment)_3020 - Correlation: 0.9973945339840685
# 263: FEAT_A: 1bb5fbdb FEAT_B: b2dba42b - Correlation: 0.9999521729413301
# 264: FEAT_A: 1bb5fbdb FEAT_B: Sandcastle Builder (Activity)_3010 - Correlation: 0.9999521729413301
# 265: FEAT_A: 1bb5fbdb FEAT_B: Sandcastle Builder (Activity)_3110 - Correlation: 1.0
# 266: FEAT_A: 65abac75 FEAT_B: Air Show_4010 - Correlation: 0.9999999999999999
# 267: FEAT_A: 14de4c5d FEAT_B: Air Show_4100 - Correlation: 1.0
# 268: FEAT_A: d122731b FEAT_B: Cart Balancer (Assessment)_4100 - Correlation: 1.0
# 269: FEAT_A: ecaab346 FEAT_B: b74258a0 - Correlation: 1.0
# 270: FEAT_A: ecaab346 FEAT_B: b2e5b0f1 - Correlation: 0.9998494646045045
# 271: FEAT_A: ecaab346 FEAT_B: Cart Balancer (Assessment)_3121 - Correlation: 1.0
# 272: FEAT_A: ecaab346 FEAT_B: Cart Balancer (Assessment)_2030 - Correlation: 1.0
# 273: FEAT_A: ecaab346 FEAT_B: Cart Balancer (Assessment)_2010 - Correlation: 0.9998494646045045
# 274: FEAT_A: 88d4a5be FEAT_B: 160654fd - Correlation: 0.9989297172615899
# 275: FEAT_A: 88d4a5be FEAT_B: Mushroom Sorter (Assessment)_3120 - Correlation: 1.0
# 276: FEAT_A: 88d4a5be FEAT_B: Mushroom Sorter (Assessment)_3020 - Correlation: 0.9989297172615899
# 277: FEAT_A: 4ef8cdd3 FEAT_B: Chow Time_4020 - Correlation: 1.0
# 278: FEAT_A: a1bbe385 FEAT_B: f28c589a - Correlation: 0.9999536797342256
# 279: FEAT_A: a1bbe385 FEAT_B: Air Show_3110 - Correlation: 1.0
# 280: FEAT_A: a1bbe385 FEAT_B: Air Show_3010 - Correlation: 0.9999536797342256
# 281: FEAT_A: 0d18d96c FEAT_B: Mushroom Sorter (Assessment)_4035 - Correlation: 1.0
# 282: FEAT_A: d185d3ea FEAT_B: Chow Time_4035 - Correlation: 1.0
# 283: FEAT_A: 90efca10 FEAT_B: Bottle Filler (Activity)_4020 - Correlation: 1.0
# 284: FEAT_A: 884228c8 FEAT_B: Fireworks (Activity)_4070 - Correlation: 1.0
# 285: FEAT_A: 99ea62f3 FEAT_B: Bubble Bath_2083 - Correlation: 1.0
# 286: FEAT_A: d51b1749 FEAT_B: Happy Camel_2080 - Correlation: 0.9999999999999998
# 287: FEAT_A: ecc6157f FEAT_B: Cart Balancer (Assessment)_4080 - Correlation: 0.9999999999999999
# 288: FEAT_A: ab4ec3a4 FEAT_B: Dino Drink_4080 - Correlation: 0.9999999999999999
# 289: FEAT_A: 7d093bf9 FEAT_B: Chow Time_2000 - Correlation: 0.9999999999999999
# 290: FEAT_A: 7040c096 FEAT_B: Scrub-A-Dub_4010 - Correlation: 1.0
# 291: FEAT_A: 5f0eb72c FEAT_B: Mushroom Sorter (Assessment)_4020 - Correlation: 1.0
# 292: FEAT_A: 3ee399c3 FEAT_B: Cauldron Filler (Assessment)_4070 - Correlation: 1.0
# 293: FEAT_A: 3d0b9317 FEAT_B: Chest Sorter (Assessment)_4040 - Correlation: 1.0
# 294: FEAT_A: 3b2048ee FEAT_B: Leaf Leader_4095 - Correlation: 1.0
# 295: FEAT_A: 04df9b66 FEAT_B: 5290eab1 - Correlation: 0.9998190477466214
# 296: FEAT_A: 04df9b66 FEAT_B: Cauldron Filler (Assessment)_3120 - Correlation: 0.9998190477466214
# 297: FEAT_A: 04df9b66 FEAT_B: Cauldron Filler (Assessment)_3020 - Correlation: 1.0
# 298: FEAT_A: 51311d7a FEAT_B: Dino Drink_2000 - Correlation: 1.0
# 299: FEAT_A: 8ac7cce4 FEAT_B: Leaf Leader_2000 - Correlation: 1.0
# 300: FEAT_A: 0d1da71f FEAT_B: Chow Time_3110 - Correlation: 0.9999999999999998
# 301: FEAT_A: 1375ccb7 FEAT_B: bdf49a58 - Correlation: 0.9993801763820361
# 302: FEAT_A: 1375ccb7 FEAT_B: Bird Measurer (Assessment)_3110 - Correlation: 0.9993801763820361
# 303: FEAT_A: 1375ccb7 FEAT_B: Bird Measurer (Assessment)_3010 - Correlation: 1.0
# 304: FEAT_A: e4d32835 FEAT_B: Pan Balance_4080 - Correlation: 1.0
# 305: FEAT_A: 7525289a FEAT_B: 45d01abe - Correlation: 0.9981555049446877
# 306: FEAT_A: 7525289a FEAT_B: Bird Measurer (Assessment)_3021 - Correlation: 0.9981555049446877
# 307: FEAT_A: 7525289a FEAT_B: Bird Measurer (Assessment)_3121 - Correlation: 1.0
# 308: FEAT_A: 8d84fa81 FEAT_B: Bubble Bath_4010 - Correlation: 1.0
# 309: FEAT_A: 3dcdda7f FEAT_B: 3ccd3f02 - Correlation: 0.9977337946782775
# 310: FEAT_A: 3dcdda7f FEAT_B: Chest Sorter (Assessment)_3110 - Correlation: 0.9977337946782775
# 311: FEAT_A: 3dcdda7f FEAT_B: Chest Sorter (Assessment)_3010 - Correlation: 1.0
# 312: FEAT_A: 7961e599 FEAT_B: 709b1251 - Correlation: 0.995000488193363
# 313: FEAT_A: 7961e599 FEAT_B: Dino Dive_2020 - Correlation: 0.9999999999999999
# 314: FEAT_A: 7961e599 FEAT_B: Dino Dive_3121 - Correlation: 0.995000488193363
# 315: FEAT_A: 7cf1bc53 FEAT_B: 3ddc79c3 - Correlation: 0.9982332387790203
# 316: FEAT_A: 7cf1bc53 FEAT_B: 3323d7e9 - Correlation: 0.9987451849599019
# 317: FEAT_A: 7cf1bc53 FEAT_B: 3babcb9b - Correlation: 0.996113675922674
# 318: FEAT_A: 7cf1bc53 FEAT_B: e720d930 - Correlation: 0.9979345979643146
# 319: FEAT_A: 7cf1bc53 FEAT_B: 5154fc30 - Correlation: 0.9961960780519679
# 320: FEAT_A: 7cf1bc53 FEAT_B: Crystals Rule_3021 - Correlation: 0.9982332387790203
# 321: FEAT_A: 7cf1bc53 FEAT_B: Crystals Rule_2030 - Correlation: 0.9987451849599019
# 322: FEAT_A: 7cf1bc53 FEAT_B: Crystals Rule_3010 - Correlation: 0.9961960780519679
# 323: FEAT_A: 7cf1bc53 FEAT_B: Crystals Rule_3121 - Correlation: 0.9979345979643146
# 324: FEAT_A: 7cf1bc53 FEAT_B: Crystals Rule_3110 - Correlation: 0.996113675922674
# 325: FEAT_A: 7cf1bc53 FEAT_B: Crystals Rule_2020 - Correlation: 0.9999999999999998
# 326: FEAT_A: 71fe8f75 FEAT_B: 0a08139c - Correlation: 0.9999850342981549
# 327: FEAT_A: 71fe8f75 FEAT_B: Bug Measurer (Activity)_3110 - Correlation: 1.0
# 328: FEAT_A: 71fe8f75 FEAT_B: Bug Measurer (Activity)_3010 - Correlation: 0.9999850342981549
# 329: FEAT_A: 06372577 FEAT_B: Air Show_2060 - Correlation: 1.0
# 330: FEAT_A: 2b058fe3 FEAT_B: Cauldron Filler (Assessment)_2010 - Correlation: 1.0
# 331: FEAT_A: a5be6304 FEAT_B: 6c930e6e - Correlation: 0.9962760616821659
# 332: FEAT_A: a5be6304 FEAT_B: Mushroom Sorter (Assessment)_2030 - Correlation: 0.9962760616821659
# 333: FEAT_A: a5be6304 FEAT_B: Mushroom Sorter (Assessment)_2010 - Correlation: 1.0
# 334: FEAT_A: 74e5f8a7 FEAT_B: Dino Drink_4020 - Correlation: 0.9999999999999999
# 335: FEAT_A: 8d748b58 FEAT_B: Bug Measurer (Activity)_4090 - Correlation: 0.9999999999999998
# 336: FEAT_A: 55115cbd FEAT_B: 6f4adc4b - Correlation: 0.9997831892615403
# 337: FEAT_A: 55115cbd FEAT_B: Bubble Bath_3021 - Correlation: 0.9997831892615403
# 338: FEAT_A: 55115cbd FEAT_B: Bubble Bath_3121 - Correlation: 1.0
# 339: FEAT_A: 792530f8 FEAT_B: Dino Drink_4030 - Correlation: 1.0
# 340: FEAT_A: 91561152 FEAT_B: Cauldron Filler (Assessment)_4025 - Correlation: 1.0
# 341: FEAT_A: 37db1c2f FEAT_B: Happy Camel_4045 - Correlation: 1.0
# 342: FEAT_A: 25fa8af4 FEAT_B: Mushroom Sorter (Assessment)_4100 - Correlation: 0.9999999999999999
# 343: FEAT_A: 01ca3a3c FEAT_B: Leaf Leader_4080 - Correlation: 0.9999999999999999
# 344: FEAT_A: 15ba1109 FEAT_B: Air Show_2000 - Correlation: 1.0
# 345: FEAT_A: 2dcad279 FEAT_B: 923afab1 - Correlation: 0.9998567985670097
# 346: FEAT_A: 2dcad279 FEAT_B: Cauldron Filler (Assessment)_3110 - Correlation: 1.0
# 347: FEAT_A: 2dcad279 FEAT_B: Cauldron Filler (Assessment)_3010 - Correlation: 0.9998567985670097
# 348: FEAT_A: cc5087a3 FEAT_B: Crystals Rule_4010 - Correlation: 0.9999999999999998
# 349: FEAT_A: 0ce40006 FEAT_B: Happy Camel_4080 - Correlation: 0.9999999999999999
# 350: FEAT_A: 611485c5 FEAT_B: Fireworks (Activity)_4080 - Correlation: 1.0
# 351: FEAT_A: a0faea5d FEAT_B: Bubble Bath_4070 - Correlation: 1.0
# 352: FEAT_A: c7f7f0e1 FEAT_B: Bug Measurer (Activity)_2000 - Correlation: 1.0
# 353: FEAT_A: 4d911100 FEAT_B: 16dffff1 - Correlation: 0.9986046680098585
# 354: FEAT_A: 4d911100 FEAT_B: 77ead60d - Correlation: 0.9998475927724755
# 355: FEAT_A: 4d911100 FEAT_B: Dino Drink_3121 - Correlation: 1.0
# 356: FEAT_A: 4d911100 FEAT_B: Dino Drink_3021 - Correlation: 0.9998475927724755
# 357: FEAT_A: 4d911100 FEAT_B: Dino Drink_2030 - Correlation: 0.9986046680098585
# 358: FEAT_A: 92687c59 FEAT_B: Scrub-A-Dub_4090 - Correlation: 1.0
# 359: FEAT_A: c952eb01 FEAT_B: Watering Hole (Activity)_4070 - Correlation: 0.9999999999999998
# 360: FEAT_A: bfc77bd6 FEAT_B: Chest Sorter (Assessment)_4080 - Correlation: 0.9999999999999998
# 361: FEAT_A: 9ee1c98c FEAT_B: Sandcastle Builder (Activity)_4021 - Correlation: 1.0
# 362: FEAT_A: fd20ea40 FEAT_B: Leaf Leader_4010 - Correlation: 0.9999999999999998
# 363: FEAT_A: d38c2fd7 FEAT_B: Bird Measurer (Assessment)_4035 - Correlation: 1.0
# 364: FEAT_A: 1b54d27f FEAT_B: Watering Hole (Activity)_2010 - Correlation: 1.0
# 365: FEAT_A: 28f975ea FEAT_B: Air Show_4020 - Correlation: 0.9999999999999999
# 366: FEAT_A: e080a381 FEAT_B: Pan Balance_4090 - Correlation: 1.0
# 367: FEAT_A: d3640339 FEAT_B: Dino Dive_4090 - Correlation: 1.0
# 368: FEAT_A: 2ec694de FEAT_B: Bug Measurer (Activity)_4080 - Correlation: 0.9999999999999998
# 369: FEAT_A: 93b353f2 FEAT_B: Chest Sorter (Assessment)_4100 - Correlation: 1.0
# 370: FEAT_A: 85d1b0de FEAT_B: Chicken Balancer (Activity)_4090 - Correlation: 0.9999999999999999
# 371: FEAT_A: de26c3a6 FEAT_B: Flower Waterer (Activity)_4020 - Correlation: 1.0
# 372: FEAT_A: 0330ab6a FEAT_B: 2230fab4 - Correlation: 0.9998673365188057
# 373: FEAT_A: 0330ab6a FEAT_B: Chow Time_3020 - Correlation: 1.0
# 374: FEAT_A: 0330ab6a FEAT_B: Chow Time_3120 - Correlation: 0.9998673365188057
# 375: FEAT_A: 15eb4a7d FEAT_B: 0413e89d - Correlation: 0.9997266832893074
# 376: FEAT_A: 15eb4a7d FEAT_B: Bubble Bath_3010 - Correlation: 0.9997266832893074
# 377: FEAT_A: 15eb4a7d FEAT_B: Bubble Bath_3110 - Correlation: 1.0
# 378: FEAT_A: 070a5291 FEAT_B: Bird Measurer (Assessment)_4100 - Correlation: 0.9999999999999999
# 379: FEAT_A: 6f445b57 FEAT_B: Chow Time_4080 - Correlation: 1.0
# 380: FEAT_A: 26a5a3dd FEAT_B: All Star Sorting_4080 - Correlation: 0.9999999999999999
# 381: FEAT_A: 7da34a02 FEAT_B: Mushroom Sorter (Assessment)_4070 - Correlation: 0.9999999999999998
# 382: FEAT_A: 857f21c0 FEAT_B: Bubble Bath_4040 - Correlation: 1.0
# 383: FEAT_A: bbfe0445 FEAT_B: 56cd3b43 - Correlation: 0.9996926215355529
# 384: FEAT_A: bbfe0445 FEAT_B: Flower Waterer (Activity)_3010 - Correlation: 0.9996926215355529
# 385: FEAT_A: bbfe0445 FEAT_B: Flower Waterer (Activity)_3110 - Correlation: 1.0
# 386: FEAT_A: a5e9da97 FEAT_B: Pan Balance_4100 - Correlation: 1.0
# 387: FEAT_A: 5e812b27 FEAT_B: Sandcastle Builder (Activity)_4030 - Correlation: 1.0
# 388: FEAT_A: 0086365d FEAT_B: Pan Balance_4010 - Correlation: 1.0
# 389: FEAT_A: f3cd5473 FEAT_B: Pan Balance_4070 - Correlation: 1.0
# 390: FEAT_A: 90d848e0 FEAT_B: Cauldron Filler (Assessment)_2000 - Correlation: 0.9999999999999999
# 391: FEAT_A: 9c5ef70c FEAT_B: Pan Balance_2000 - Correlation: 1.0
# 392: FEAT_A: 86ba578b FEAT_B: Leaf Leader_2070 - Correlation: 1.0
# 393: FEAT_A: 6aeafed4 FEAT_B: Bubble Bath_4090 - Correlation: 0.9999999999999998
# 394: FEAT_A: beb0a7b9 FEAT_B: b88f38da - Correlation: 0.9999125179829763
# 395: FEAT_A: beb0a7b9 FEAT_B: Fireworks (Activity)_3110 - Correlation: 0.9999125179829763
# 396: FEAT_A: beb0a7b9 FEAT_B: Fireworks (Activity)_3010 - Correlation: 1.0
# 397: FEAT_A: d2278a3b FEAT_B: Bottle Filler (Activity)_2000 - Correlation: 1.0
# 398: FEAT_A: f56e0afc FEAT_B: Bird Measurer (Assessment)_2000 - Correlation: 1.0
# 399: FEAT_A: f93fc684 FEAT_B: Chow Time_4010 - Correlation: 1.0
# 400: FEAT_A: 3393b68b FEAT_B: Bird Measurer (Assessment)_2010 - Correlation: 1.0
# 401: FEAT_A: 022b4259 FEAT_B: Bug Measurer (Activity)_4025 - Correlation: 0.9999999999999998
# 402: FEAT_A: 3edf6747 FEAT_B: Cauldron Filler (Assessment)_4035 - Correlation: 1.0
# 403: FEAT_A: 19967db1 FEAT_B: Chow Time_4090 - Correlation: 0.9999999999999998
# 404: FEAT_A: 392e14df FEAT_B: Cauldron Filler (Assessment)_4100 - Correlation: 1.0
# 405: FEAT_A: 46b50ba8 FEAT_B: Happy Camel_4095 - Correlation: 1.0
# 406: FEAT_A: 9554a50b FEAT_B: Cauldron Filler (Assessment)_4080 - Correlation: 0.9999999999999999
# 407: FEAT_A: 499edb7c FEAT_B: Chicken Balancer (Activity)_4020 - Correlation: 1.0
# 408: FEAT_A: a16a373e FEAT_B: Bird Measurer (Assessment)_4070 - Correlation: 1.0
# 409: FEAT_A: d3f1e122 FEAT_B: Bottle Filler (Activity)_4035 - Correlation: 1.0
# 410: FEAT_A: 461eace6 FEAT_B: Egg Dropper (Activity)_4020 - Correlation: 1.0
# 411: FEAT_A: dcb55a27 FEAT_B: Air Show_4110 - Correlation: 1.0
# 412: FEAT_A: 795e4a37 FEAT_B: Cart Balancer (Assessment)_3010 - Correlation: 0.9999999999999998
# 413: FEAT_A: 47efca07 FEAT_B: Bottle Filler (Activity)_4090 - Correlation: 1.0
# 414: FEAT_A: 5be391b5 FEAT_B: Dino Drink_4010 - Correlation: 1.0
# 415: FEAT_A: 5859dfb6 FEAT_B: 90ea0bac - Correlation: 0.9981052472610571
# 416: FEAT_A: 5859dfb6 FEAT_B: Bubble Bath_3120 - Correlation: 1.0
# 417: FEAT_A: 5859dfb6 FEAT_B: Bubble Bath_3020 - Correlation: 0.9981052472610571
# 418: FEAT_A: f54238ee FEAT_B: Fireworks (Activity)_4090 - Correlation: 0.9999999999999998
# 419: FEAT_A: 2fb91ec1 FEAT_B: d2e9262e - Correlation: 0.9991434495208746
# 420: FEAT_A: 2fb91ec1 FEAT_B: Watering Hole (Activity)_4025 - Correlation: 0.9999999999999998
# 421: FEAT_A: 2fb91ec1 FEAT_B: Watering Hole (Activity)_4020 - Correlation: 0.9991434495208746
# 422: FEAT_A: cf82af56 FEAT_B: Scrub-A-Dub_4070 - Correlation: 1.0
# 423: FEAT_A: e79f3763 FEAT_B: Bug Measurer (Activity)_4030 - Correlation: 1.0
# 424: FEAT_A: cfbd47c8 FEAT_B: Chow Time_4030 - Correlation: 1.0
# 425: FEAT_A: c0415e5c FEAT_B: Dino Dive_4020 - Correlation: 1.0
# 426: FEAT_A: 67aa2ada FEAT_B: Leaf Leader_4090 - Correlation: 1.0
# 427: FEAT_A: 84b0e0c8 FEAT_B: ea321fb1 - Correlation: 0.9993007600205116
# 428: FEAT_A: 84b0e0c8 FEAT_B: Chicken Balancer (Activity)_3110 - Correlation: 1.0
# 429: FEAT_A: 84b0e0c8 FEAT_B: Chicken Balancer (Activity)_3010 - Correlation: 0.9993007600205116
# 430: FEAT_A: fcfdffb6 FEAT_B: Flower Waterer (Activity)_4022 - Correlation: 1.0
# 431: FEAT_A: 5348fd84 FEAT_B: Cauldron Filler (Assessment)_4040 - Correlation: 1.0
# 432: FEAT_A: a52b92d5 FEAT_B: a1e4395d - Correlation: 0.9991003891313356
# 433: FEAT_A: a52b92d5 FEAT_B: Mushroom Sorter (Assessment)_3010 - Correlation: 0.9991003891313356
# 434: FEAT_A: a52b92d5 FEAT_B: Mushroom Sorter (Assessment)_3110 - Correlation: 1.0
# 435: FEAT_A: 3d63345e FEAT_B: Cart Balancer (Assessment)_4035 - Correlation: 0.9999999999999999
# 436: FEAT_A: 3d8c61b0 FEAT_B: Happy Camel_4030 - Correlation: 1.0
# 437: FEAT_A: 828e68f9 FEAT_B: Cart Balancer (Assessment)_3110 - Correlation: 1.0
# 438: FEAT_A: 46cd75b4 FEAT_B: Chicken Balancer (Activity)_4022 - Correlation: 1.0
# 439: FEAT_A: 84538528 FEAT_B: Sandcastle Builder (Activity)_4020 - Correlation: 1.0
# 440: FEAT_A: 87d743c1 FEAT_B: Dino Dive_4010 - Correlation: 1.0
# 441: FEAT_A: cb1178ad FEAT_B: Chest Sorter (Assessment)_4090 - Correlation: 1.0
# 442: FEAT_A: c58186bf FEAT_B: Sandcastle Builder (Activity)_4035 - Correlation: 1.0
# 443: FEAT_A: a8efe47b FEAT_B: Chest Sorter (Assessment)_4030 - Correlation: 1.0
# 444: FEAT_A: 6c517a88 FEAT_B: Dino Drink_4070 - Correlation: 1.0
# 445: FEAT_A: 4e5fc6f5 FEAT_B: Cart Balancer (Assessment)_4090 - Correlation: 0.9999999999999999
# 446: FEAT_A: 37937459 FEAT_B: Sandcastle Builder (Activity)_4090 - Correlation: 1.0
# 447: FEAT_A: c2baf0bd FEAT_B: Happy Camel_2020 - Correlation: 1.0
# 448: FEAT_A: 86c924c4 FEAT_B: Crystals Rule_4020 - Correlation: 1.0
# 449: FEAT_A: 6d90d394 FEAT_B: Scrub-A-Dub_2000 - Correlation: 1.0
# 450: FEAT_A: 8af75982 FEAT_B: Happy Camel_4020 - Correlation: 1.0
# 451: FEAT_A: a8876db3 FEAT_B: Cart Balancer (Assessment)_3021 - Correlation: 1.0
# 452: FEAT_A: 7d5c30a2 FEAT_B: Dino Dive_2060 - Correlation: 1.0
# 453: FEAT_A: 4c2ec19f FEAT_B: Egg Dropper (Activity)_4025 - Correlation: 1.0
# 454: FEAT_A: 5c2f29ca FEAT_B: Cart Balancer (Assessment)_4020 - Correlation: 1.0
# 455: FEAT_A: b1d5101d FEAT_B: All Star Sorting_4095 - Correlation: 1.0
# 456: FEAT_A: a44b10dc FEAT_B: Flower Waterer (Activity)_4070 - Correlation: 1.0
# 457: FEAT_A: 565a3990 FEAT_B: Bug Measurer (Activity)_4070 - Correlation: 1.0
# 458: FEAT_A: a2df0760 FEAT_B: Happy Camel_4035 - Correlation: 0.9999999999999999
# 459: FEAT_A: e3ff61fb FEAT_B: Dino Dive_3021 - Correlation: 1.0
# 460: FEAT_A: ab3136ba FEAT_B: 832735e1 - Correlation: 0.9998637945770238
# 461: FEAT_A: ab3136ba FEAT_B: Dino Dive_3010 - Correlation: 0.9998637945770238
# 462: FEAT_A: ab3136ba FEAT_B: Dino Dive_3110 - Correlation: 1.0
# 463: FEAT_A: 5f5b2617 FEAT_B: Bottle Filler (Activity)_4080 - Correlation: 0.9999999999999999
# 464: FEAT_A: bd612267 FEAT_B: Chest Sorter (Assessment)_4070 - Correlation: 0.9999999999999999
# 465: FEAT_A: 5e3ea25a FEAT_B: Crystals Rule_4070 - Correlation: 1.0
# 466: FEAT_A: 93edfe2e FEAT_B: Crystals Rule_4090 - Correlation: 1.0
# 467: FEAT_A: 119b5b02 FEAT_B: Dino Dive_4080 - Correlation: 0.9999999999999998
# 468: FEAT_A: 02a42007 FEAT_B: Fireworks (Activity)_4030 - Correlation: 1.0
# 469: FEAT_A: 2a444e03 FEAT_B: Pan Balance_4030 - Correlation: 1.0
# 470: FEAT_A: 262136f4 FEAT_B: Leaf Leader_4020 - Correlation: 1.0
# 471: FEAT_A: e694a35b FEAT_B: Fireworks (Activity)_4020 - Correlation: 1.0
# 472: FEAT_A: 3bf1cf26 FEAT_B: 1af8be29 - Correlation: 0.9998900847287066
# 473: FEAT_A: 3bf1cf26 FEAT_B: Happy Camel_3120 - Correlation: 0.9999999999999999
# 474: FEAT_A: 3bf1cf26 FEAT_B: Happy Camel_3020 - Correlation: 0.9998900847287066
# 475: FEAT_A: 5e109ec3 FEAT_B: Cart Balancer (Assessment)_4030 - Correlation: 0.9999999999999999
# 476: FEAT_A: 804ee27f FEAT_B: Pan Balance_4020 - Correlation: 1.0
# 477: FEAT_A: 3bb91ced FEAT_B: Happy Camel_2081 - Correlation: 1.0
# 478: FEAT_A: 5d042115 FEAT_B: Flower Waterer (Activity)_4030 - Correlation: 0.9999999999999999
# 479: FEAT_A: 4d6737eb FEAT_B: Dino Drink_2070 - Correlation: 0.9999999999999998
# 480: FEAT_A: c1cac9a2 FEAT_B: Scrub-A-Dub_2081 - Correlation: 1.0
# 481: FEAT_A: 0db6d71d FEAT_B: Chest Sorter (Assessment)_4020 - Correlation: 1.0
# 482: FEAT_A: 532a2afb FEAT_B: Cauldron Filler (Assessment)_2020 - Correlation: 1.0
# 483: FEAT_A: eb2c19cd FEAT_B: Mushroom Sorter (Assessment)_4090 - Correlation: 1.0
# 484: FEAT_A: 7dfe6d8a FEAT_B: Leaf Leader_4070 - Correlation: 0.9999999999999998
# 485: FEAT_A: 9b01374f FEAT_B: Flower Waterer (Activity)_2000 - Correlation: 1.0
# 486: FEAT_A: 51102b85 FEAT_B: Bird Measurer (Assessment)_4030 - Correlation: 1.0
# 487: FEAT_A: Lifting Heavy Things FEAT_B: Lifting Heavy Things_2000 - Correlation: 1.0
# 488: FEAT_A: Crystal Caves - Level 3 FEAT_B: Crystal Caves - Level 3_2000 - Correlation: 0.9999999999999998
# 489: FEAT_A: Tree Top City - Level 1 FEAT_B: Tree Top City - Level 1_2000 - Correlation: 1.0
# 490: FEAT_A: Heavy, Heavier, Heaviest FEAT_B: Heavy, Heavier, Heaviest_2000 - Correlation: 0.9999999999999998
# 491: FEAT_A: Magma Peak - Level 2 FEAT_B: Magma Peak - Level 2_2000 - Correlation: 1.0
# 492: FEAT_A: Rulers FEAT_B: Rulers_2000 - Correlation: 1.0
# 493: FEAT_A: Slop Problem FEAT_B: Slop Problem_2000 - Correlation: 1.0
# 494: FEAT_A: Pirate's Tale FEAT_B: Pirate's Tale_2000 - Correlation: 1.0
# 495: FEAT_A: 12 Monkeys FEAT_B: 12 Monkeys_2000 - Correlation: 1.0
# 496: FEAT_A: Crystal Caves - Level 2 FEAT_B: Crystal Caves - Level 2_2000 - Correlation: 0.9999999999999998
# 497: FEAT_A: Tree Top City - Level 2 FEAT_B: Tree Top City - Level 2_2000 - Correlation: 1.0
# 498: FEAT_A: Balancing Act FEAT_B: Balancing Act_2000 - Correlation: 1.0
# 499: FEAT_A: Ordering Spheres FEAT_B: Ordering Spheres_2000 - Correlation: 0.9999999999999998
# 500: FEAT_A: Honey Cake FEAT_B: Honey Cake_2000 - Correlation: 1.0
# 501: FEAT_A: Welcome to Lost Lagoon! FEAT_B: Welcome to Lost Lagoon!_2000 - Correlation: 1.0
# 502: FEAT_A: Magma Peak - Level 1 FEAT_B: Magma Peak - Level 1_2000 - Correlation: 1.0
# 503: FEAT_A: Costume Box FEAT_B: Costume Box_2000 - Correlation: 1.0
# 504: FEAT_A: Tree Top City - Level 3 FEAT_B: Tree Top City - Level 3_2000 - Correlation: 0.9999999999999998
# 505: FEAT_A: Crystal Caves - Level 1 FEAT_B: Crystal Caves - Level 1_2000 - Correlation: 1.0
# 506: FEAT_A: Treasure Map FEAT_B: Treasure Map_2000 - Correlation: 1.0
# 507: FEAT_A: var_event_id FEAT_B: var_title_event_code - Correlation: 0.9995254184300612

# %%
to_exclude = [] 
ajusted_test = reduce_test.copy()
for feature in ajusted_test.columns:
    if feature not in ['accuracy_group', 'installation_id', 'accuracy_group', 'session_title']:
        data = reduce_train[feature]
        train_mean = data.mean()
        data = ajusted_test[feature] 
        test_mean = data.mean()
        try:
            error = stract_hists(feature, adjust=True)
            ajust_factor = train_mean / test_mean
            if ajust_factor > 10 or ajust_factor < 0.1:# or error > 0.01:
                to_exclude.append(feature)
                print(feature, train_mean, test_mean, error)
            else:
                ajusted_test[feature] *= ajust_factor
        except:
            to_exclude.append(feature)
            print(feature, train_mean, test_mean)
# Out:
# acc_Cart Balancer (Assessment) -0.04020325710970116 -0.47065833333333346 0.006732930476733109
# 17ca3959 0.0 0.0
# 4074bac2 0.0 0.0
# 13f56524 0.04392312040700961 0.0
# 7fd1ac25 0.01978518937252685 0.0
# 003cd2ee 0.0 0.0
# 29a42aea 0.004070096099491238 0.0
# ecc6157f 0.007292255511588468 0.0
# ab4ec3a4 0.0009044657998869418 0.0
# e4d32835 0.0013001695873374789 0.0
# 5dc079d8 0.0 0.0
# 01ca3a3c 0.0004522328999434709 0.0
# 0ce40006 0.0008479366873940079 0.0
# 611485c5 0.0013566986998304127 0.0
# bfc77bd6 0.012832108535895986 0.0
# 1b54d27f 0.0007348784624081402 0.0
# 2ec694de 0.008988128886376484 0.0
# 6aeafed4 0.14703222159412097 0.008 0.0
# dcb1663e 0.0 0.0
# a8cc6fec 0.0 0.0
# 119b5b02 0.0002826455624646693 0.0
# eb2c19cd 0.17382702091577162 0.008 0.0
# Leaf Leader_4080 0.0004522328999434709 0.0
# Chest Sorter (Assessment)_4080 0.012832108535895986 0.0
# Dino Dive_4080 0.0002826455624646693 0.0
# Cart Balancer (Assessment)_4080 0.007292255511588468 0.0
# Crystals Rule_2010 0.0 0.0
# Pan Balance_2010 0.0 0.0
# Scrub-A-Dub_4080 0.0 0.0
# Sandcastle Builder (Activity)_2010 0.0 0.0
# Bug Measurer (Activity)_4080 0.008988128886376484 0.0
# Bubble Bath_4080 0.004070096099491238 0.0
# Bubble Bath_4090 0.14703222159412097 0.008 0.0
# Bottle Filler (Activity)_2010 0.0 0.0
# Mushroom Sorter (Assessment)_4090 0.17382702091577162 0.008 0.0
# Air Show_4080 0.0 0.0
# Egg Dropper (Activity)_4080 0.01978518937252685 0.0
# Watering Hole (Activity)_2010 0.0007348784624081402 0.0
# Pan Balance_4080 0.0013001695873374789 0.0
# Dino Drink_4080 0.0009044657998869418 0.0
# Happy Camel_4080 0.0008479366873940079 0.0
# Fireworks (Activity)_4080 0.0013566986998304127 0.0
# Mushroom Sorter (Assessment)_4080 0.04392312040700961 0.0

# %%
features = [x for x in features if x not in (to_exclude + to_remove)]
reduce_train[features].shape
# Out:
# (17690, 364)

# %%
#cat_model = Catb_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
lgb_model = Lgb_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
xgb_model = Xgb_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
# Out:
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:153: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:1243: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.035	valid_1's rmse: 1.05355
# [200]	training's rmse: 0.967006	valid_1's rmse: 1.00437
# [300]	training's rmse: 0.933475	valid_1's rmse: 0.988181
# [400]	training's rmse: 0.909597	valid_1's rmse: 0.981152
# [500]	training's rmse: 0.890431	valid_1's rmse: 0.978223
# [600]	training's rmse: 0.873906	valid_1's rmse: 0.97623
# [700]	training's rmse: 0.859056	valid_1's rmse: 0.975433
# [800]	training's rmse: 0.845504	valid_1's rmse: 0.974671
# Early stopping, best iteration is:
# [781]	training's rmse: 0.847961	valid_1's rmse: 0.974495
# Partial score of fold 0 is: 0.6023759776507782
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.03315	valid_1's rmse: 1.05301
# [200]	training's rmse: 0.964675	valid_1's rmse: 1.0078
# [300]	training's rmse: 0.930385	valid_1's rmse: 0.99545
# [400]	training's rmse: 0.905971	valid_1's rmse: 0.991384
# [500]	training's rmse: 0.886735	valid_1's rmse: 0.990031
# [600]	training's rmse: 0.870614	valid_1's rmse: 0.989462
# Early stopping, best iteration is:
# [573]	training's rmse: 0.874887	valid_1's rmse: 0.989325
# Partial score of fold 1 is: 0.5859457061929877
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.03314	valid_1's rmse: 1.05534
# [200]	training's rmse: 0.964809	valid_1's rmse: 1.00806
# [300]	training's rmse: 0.931018	valid_1's rmse: 0.993541
# [400]	training's rmse: 0.907519	valid_1's rmse: 0.987472
# [500]	training's rmse: 0.888401	valid_1's rmse: 0.98508
# [600]	training's rmse: 0.871888	valid_1's rmse: 0.984083
# [700]	training's rmse: 0.857167	valid_1's rmse: 0.983693
# [800]	training's rmse: 0.843624	valid_1's rmse: 0.983358
# Early stopping, best iteration is:
# [799]	training's rmse: 0.843754	valid_1's rmse: 0.983325
# Partial score of fold 2 is: 0.5889875916703944
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.03529	valid_1's rmse: 1.05762
# [200]	training's rmse: 0.96572	valid_1's rmse: 1.00967
# [300]	training's rmse: 0.931265	valid_1's rmse: 0.995029
# [400]	training's rmse: 0.907519	valid_1's rmse: 0.989549
# [500]	training's rmse: 0.888318	valid_1's rmse: 0.986928
# [600]	training's rmse: 0.871684	valid_1's rmse: 0.985464
# [700]	training's rmse: 0.856691	valid_1's rmse: 0.984379
# [800]	training's rmse: 0.842924	valid_1's rmse: 0.983842
# [900]	training's rmse: 0.829806	valid_1's rmse: 0.983847
# Early stopping, best iteration is:
# [812]	training's rmse: 0.841224	valid_1's rmse: 0.983754
# Partial score of fold 3 is: 0.5972185759033773
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.03501	valid_1's rmse: 1.05964
# [200]	training's rmse: 0.96586	valid_1's rmse: 1.01193
# [300]	training's rmse: 0.931823	valid_1's rmse: 0.995421
# [400]	training's rmse: 0.907977	valid_1's rmse: 0.988449
# [500]	training's rmse: 0.888912	valid_1's rmse: 0.985206
# [600]	training's rmse: 0.87252	valid_1's rmse: 0.983213
# [700]	training's rmse: 0.857521	valid_1's rmse: 0.982163
# [800]	training's rmse: 0.843823	valid_1's rmse: 0.981754
# [900]	training's rmse: 0.83087	valid_1's rmse: 0.981106
# [1000]	training's rmse: 0.818675	valid_1's rmse: 0.98087
# [1100]	training's rmse: 0.807317	valid_1's rmse: 0.980969
# Early stopping, best iteration is:
# [1006]	training's rmse: 0.817941	valid_1's rmse: 0.980805
# Partial score of fold 4 is: 0.5858574683259025
# Our oof cohen kappa score is:  0.5919174340144515
# /opt/conda/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-rmse:1.85772	val-rmse:1.8588
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.01146	val-rmse:1.15565
# [200]	train-rmse:0.726643	val-rmse:1.01029
# [300]	train-rmse:0.610465	val-rmse:0.98726
# [400]	train-rmse:0.54795	val-rmse:0.984103
# [500]	train-rmse:0.512312	val-rmse:0.984422
# Stopping. Best iteration:
# [441]	train-rmse:0.530045	val-rmse:0.984054
#
# Partial score of fold 0 is: 0.5949492461642929
# [0]	train-rmse:1.85764	val-rmse:1.85926
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.00862	val-rmse:1.16745
# [200]	train-rmse:0.719111	val-rmse:1.02171
# [300]	train-rmse:0.59987	val-rmse:0.996911
# [400]	train-rmse:0.536866	val-rmse:0.992303
# Stopping. Best iteration:
# [397]	train-rmse:0.538303	val-rmse:0.99224
#
# Partial score of fold 1 is: 0.5795040663584793
# [0]	train-rmse:1.85763	val-rmse:1.85901
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.00906	val-rmse:1.156
# [200]	train-rmse:0.721954	val-rmse:1.01225
# [300]	train-rmse:0.604373	val-rmse:0.990273
# [400]	train-rmse:0.541222	val-rmse:0.988493
# Stopping. Best iteration:
# [357]	train-rmse:0.564521	val-rmse:0.988327
#
# Partial score of fold 2 is: 0.5864825095125301
# [0]	train-rmse:1.85768	val-rmse:1.85909
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.01242	val-rmse:1.15649
# [200]	train-rmse:0.726143	val-rmse:1.01267
# [300]	train-rmse:0.610328	val-rmse:0.991076
# [400]	train-rmse:0.549801	val-rmse:0.987518
# [500]	train-rmse:0.512661	val-rmse:0.987691
# Stopping. Best iteration:
# [427]	train-rmse:0.538246	val-rmse:0.987384
#
# Partial score of fold 3 is: 0.5918505427079537
# [0]	train-rmse:1.85759	val-rmse:1.85915
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.00609	val-rmse:1.16125
# [200]	train-rmse:0.720829	val-rmse:1.01746
# [300]	train-rmse:0.607824	val-rmse:0.994572
# [400]	train-rmse:0.546223	val-rmse:0.990968
# [500]	train-rmse:0.505737	val-rmse:0.991197
# Stopping. Best iteration:
# [407]	train-rmse:0.542753	val-rmse:0.990836
#
# Partial score of fold 4 is: 0.5779809732346294
# Our oof cohen kappa score is:  0.5859762214242392

# %%
#cnn_model = Cnn_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
nn_model = Nn_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:100: DeprecationWarning: The ``active_features_`` attribute was deprecated in version 0.20 and will be removed 0.22.
#   warnings.warn(msg, category=DeprecationWarning)
# (17690, 369)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 200)               74000
# _________________________________________________________________
# layer_normalization (LayerNo (None, 200)               400
# _________________________________________________________________
# dropout (Dropout)            (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               20100
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 100)               200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 50)                100
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 25)                1275
# _________________________________________________________________
# layer_normalization_3 (Layer (None, 25)                50
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 101,201
# Trainable params: 101,201
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 14151 samples, validate on 3539 samples
# Epoch 1/100
# 13792/14151 [============================>.] - ETA: 0s - loss: 1.7896
# Epoch 00001: val_loss improved from inf to 1.12740, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 209us/sample - loss: 1.7804 - val_loss: 1.1274
# Epoch 2/100
# 13824/14151 [============================>.] - ETA: 0s - loss: 1.3483
# Epoch 00002: val_loss improved from 1.12740 to 1.09061, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 154us/sample - loss: 1.3447 - val_loss: 1.0906
# Epoch 3/100
# 14144/14151 [============================>.] - ETA: 0s - loss: 1.2413
# Epoch 00003: val_loss improved from 1.09061 to 1.05410, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 156us/sample - loss: 1.2418 - val_loss: 1.0541
# Epoch 4/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 1.2024
# Epoch 00004: val_loss improved from 1.05410 to 1.04000, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 157us/sample - loss: 1.2019 - val_loss: 1.0400
# Epoch 5/100
# 13824/14151 [============================>.] - ETA: 0s - loss: 1.1754
# Epoch 00005: val_loss improved from 1.04000 to 1.03002, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 155us/sample - loss: 1.1725 - val_loss: 1.0300
# Epoch 6/100
# 13792/14151 [============================>.] - ETA: 0s - loss: 1.1576
# Epoch 00006: val_loss improved from 1.03002 to 1.02915, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 155us/sample - loss: 1.1572 - val_loss: 1.0292
# Epoch 7/100
# 13856/14151 [============================>.] - ETA: 0s - loss: 1.1320
# Epoch 00007: val_loss improved from 1.02915 to 1.01690, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 159us/sample - loss: 1.1327 - val_loss: 1.0169
# Epoch 8/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 1.1224
# Epoch 00008: val_loss improved from 1.01690 to 1.01268, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 170us/sample - loss: 1.1233 - val_loss: 1.0127
# Epoch 9/100
# 14144/14151 [============================>.] - ETA: 0s - loss: 1.1178
# Epoch 00009: val_loss improved from 1.01268 to 1.00966, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 171us/sample - loss: 1.1183 - val_loss: 1.0097
# Epoch 10/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 1.0914
# Epoch 00010: val_loss did not improve from 1.00966
# 14151/14151 [==============================] - 2s 169us/sample - loss: 1.0921 - val_loss: 1.0275
# Epoch 11/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 1.0884
# Epoch 00011: val_loss improved from 1.00966 to 1.00327, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 168us/sample - loss: 1.0891 - val_loss: 1.0033
# Epoch 12/100
# 13856/14151 [============================>.] - ETA: 0s - loss: 1.0784
# Epoch 00012: val_loss improved from 1.00327 to 0.99614, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 168us/sample - loss: 1.0823 - val_loss: 0.9961
# Epoch 13/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 1.0710
# Epoch 00013: val_loss improved from 0.99614 to 0.98799, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 157us/sample - loss: 1.0687 - val_loss: 0.9880
# Epoch 14/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 1.0504
# Epoch 00014: val_loss improved from 0.98799 to 0.98284, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 160us/sample - loss: 1.0504 - val_loss: 0.9828
# Epoch 15/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 1.0387
# Epoch 00015: val_loss improved from 0.98284 to 0.97437, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 156us/sample - loss: 1.0388 - val_loss: 0.9744
# Epoch 16/100
# 14080/14151 [============================>.] - ETA: 0s - loss: 1.0292
# Epoch 00016: val_loss did not improve from 0.97437
# 14151/14151 [==============================] - 2s 156us/sample - loss: 1.0296 - val_loss: 0.9834
# Epoch 17/100
# 14080/14151 [============================>.] - ETA: 0s - loss: 1.0242
# Epoch 00017: val_loss did not improve from 0.97437
# 14151/14151 [==============================] - 2s 155us/sample - loss: 1.0250 - val_loss: 0.9781
# Epoch 18/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 1.0105
# Epoch 00018: val_loss did not improve from 0.97437
# 14151/14151 [==============================] - 2s 156us/sample - loss: 1.0107 - val_loss: 0.9753
# Epoch 19/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 1.0042
# Epoch 00019: val_loss did not improve from 0.97437
# 14151/14151 [==============================] - 2s 155us/sample - loss: 1.0055 - val_loss: 0.9879
# Epoch 20/100
# 13856/14151 [============================>.] - ETA: 0s - loss: 0.9970
# Epoch 00020: val_loss did not improve from 0.97437
# 14151/14151 [==============================] - 2s 153us/sample - loss: 0.9959 - val_loss: 0.9897
# Epoch 21/100
# 13824/14151 [============================>.] - ETA: 0s - loss: 0.9963
# Epoch 00021: val_loss improved from 0.97437 to 0.97294, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 155us/sample - loss: 0.9969 - val_loss: 0.9729
# Epoch 22/100
# 13984/14151 [============================>.] - ETA: 0s - loss: 0.9881
# Epoch 00022: val_loss improved from 0.97294 to 0.97150, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 158us/sample - loss: 0.9897 - val_loss: 0.9715
# Epoch 23/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 0.9812
# Epoch 00023: val_loss did not improve from 0.97150
# 14151/14151 [==============================] - 2s 156us/sample - loss: 0.9811 - val_loss: 0.9826
# Epoch 24/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 0.9649
# Epoch 00024: val_loss did not improve from 0.97150
# 14151/14151 [==============================] - 2s 156us/sample - loss: 0.9640 - val_loss: 0.9872
# Epoch 25/100
# 13824/14151 [============================>.] - ETA: 0s - loss: 0.9630
# Epoch 00025: val_loss improved from 0.97150 to 0.96884, saving model to nn_model.w8
# 14151/14151 [==============================] - 2s 155us/sample - loss: 0.9618 - val_loss: 0.9688
# Epoch 26/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 0.9542
# Epoch 00026: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 157us/sample - loss: 0.9585 - val_loss: 0.9781
# Epoch 27/100
# 13792/14151 [============================>.] - ETA: 0s - loss: 0.9392
# Epoch 00027: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 154us/sample - loss: 0.9430 - val_loss: 0.9871
# Epoch 28/100
# 14080/14151 [============================>.] - ETA: 0s - loss: 0.9362
# Epoch 00028: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 155us/sample - loss: 0.9351 - val_loss: 0.9742
# Epoch 29/100
# 13792/14151 [============================>.] - ETA: 0s - loss: 0.9346
# Epoch 00029: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 153us/sample - loss: 0.9345 - val_loss: 0.9806
# Epoch 30/100
# 14144/14151 [============================>.] - ETA: 0s - loss: 0.9316
# Epoch 00030: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 154us/sample - loss: 0.9313 - val_loss: 0.9907
# Epoch 31/100
# 13856/14151 [============================>.] - ETA: 0s - loss: 0.9054
# Epoch 00031: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 153us/sample - loss: 0.9081 - val_loss: 1.0030
# Epoch 32/100
# 13792/14151 [============================>.] - ETA: 0s - loss: 0.9142
# Epoch 00032: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 154us/sample - loss: 0.9132 - val_loss: 0.9809
# Epoch 33/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 0.9116
# Epoch 00033: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 155us/sample - loss: 0.9117 - val_loss: 0.9723
# Epoch 34/100
# 13824/14151 [============================>.] - ETA: 0s - loss: 0.9008
# Epoch 00034: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 153us/sample - loss: 0.9009 - val_loss: 0.9914
# Epoch 35/100
# 13792/14151 [============================>.] - ETA: 0s - loss: 0.8898
# Epoch 00035: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 153us/sample - loss: 0.8898 - val_loss: 0.9792
# Epoch 36/100
# 13824/14151 [============================>.] - ETA: 0s - loss: 0.8779
# Epoch 00036: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 153us/sample - loss: 0.8792 - val_loss: 0.9872
# Epoch 37/100
# 14144/14151 [============================>.] - ETA: 0s - loss: 0.8887
# Epoch 00037: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 154us/sample - loss: 0.8885 - val_loss: 0.9692
# Epoch 38/100
# 13792/14151 [============================>.] - ETA: 0s - loss: 0.8835
# Epoch 00038: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 155us/sample - loss: 0.8839 - val_loss: 0.9778
# Epoch 39/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 0.8739
# Epoch 00039: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 160us/sample - loss: 0.8741 - val_loss: 0.9841
# Epoch 40/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 0.8556
# Epoch 00040: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 158us/sample - loss: 0.8547 - val_loss: 0.9768
# Epoch 41/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 0.8592
# Epoch 00041: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 158us/sample - loss: 0.8594 - val_loss: 1.0040
# Epoch 42/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 0.8483
# Epoch 00042: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 3s 220us/sample - loss: 0.8483 - val_loss: 0.9812
# Epoch 43/100
# 13920/14151 [============================>.] - ETA: 0s - loss: 0.8658
# Epoch 00043: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 3s 227us/sample - loss: 0.8663 - val_loss: 0.9886
# Epoch 44/100
# 13792/14151 [============================>.] - ETA: 0s - loss: 0.8399
# Epoch 00044: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 154us/sample - loss: 0.8381 - val_loss: 1.0262
# Epoch 45/100
# 13824/14151 [============================>.] - ETA: 0s - loss: 0.8328
# Epoch 00045: val_loss did not improve from 0.96884
# 14151/14151 [==============================] - 2s 154us/sample - loss: 0.8315 - val_loss: 1.0087
# Partial score of fold 0 is: 0.5935179714157568
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 200)               74000
# _________________________________________________________________
# layer_normalization_4 (Layer (None, 200)               400
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               20100
# _________________________________________________________________
# layer_normalization_5 (Layer (None, 100)               200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                5050
# _________________________________________________________________
# layer_normalization_6 (Layer (None, 50)                100
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 25)                1275
# _________________________________________________________________
# layer_normalization_7 (Layer (None, 25)                50
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 101,201
# Trainable params: 101,201
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 14152 samples, validate on 3538 samples
# Epoch 1/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 1.9269
# Epoch 00001: val_loss improved from inf to 1.11851, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 196us/sample - loss: 1.9214 - val_loss: 1.1185
# Epoch 2/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.3844
# Epoch 00002: val_loss improved from 1.11851 to 1.06615, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 156us/sample - loss: 1.3843 - val_loss: 1.0662
# Epoch 3/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 1.2961
# Epoch 00003: val_loss improved from 1.06615 to 1.05453, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 154us/sample - loss: 1.2946 - val_loss: 1.0545
# Epoch 4/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 1.2287
# Epoch 00004: val_loss improved from 1.05453 to 1.04523, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 152us/sample - loss: 1.2270 - val_loss: 1.0452
# Epoch 5/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.1919
# Epoch 00005: val_loss did not improve from 1.04523
# 14152/14152 [==============================] - 2s 152us/sample - loss: 1.1942 - val_loss: 1.0630
# Epoch 6/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 1.1721
# Epoch 00006: val_loss improved from 1.04523 to 1.03142, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 154us/sample - loss: 1.1716 - val_loss: 1.0314
# Epoch 7/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 1.1588
# Epoch 00007: val_loss did not improve from 1.03142
# 14152/14152 [==============================] - 2s 154us/sample - loss: 1.1575 - val_loss: 1.0376
# Epoch 8/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.1358
# Epoch 00008: val_loss improved from 1.03142 to 1.02667, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 152us/sample - loss: 1.1371 - val_loss: 1.0267
# Epoch 9/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.1345
# Epoch 00009: val_loss did not improve from 1.02667
# 14152/14152 [==============================] - 2s 151us/sample - loss: 1.1322 - val_loss: 1.0325
# Epoch 10/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 1.0996
# Epoch 00010: val_loss improved from 1.02667 to 1.02615, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 152us/sample - loss: 1.1025 - val_loss: 1.0261
# Epoch 11/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 1.0889
# Epoch 00011: val_loss improved from 1.02615 to 1.02391, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 154us/sample - loss: 1.0891 - val_loss: 1.0239
# Epoch 12/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.0897
# Epoch 00012: val_loss did not improve from 1.02391
# 14152/14152 [==============================] - 2s 151us/sample - loss: 1.0875 - val_loss: 1.0628
# Epoch 13/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.0660
# Epoch 00013: val_loss did not improve from 1.02391
# 14152/14152 [==============================] - 2s 152us/sample - loss: 1.0627 - val_loss: 1.0298
# Epoch 14/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.0515
# Epoch 00014: val_loss improved from 1.02391 to 1.00586, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 151us/sample - loss: 1.0527 - val_loss: 1.0059
# Epoch 15/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 1.0530
# Epoch 00015: val_loss did not improve from 1.00586
# 14152/14152 [==============================] - 2s 151us/sample - loss: 1.0514 - val_loss: 1.0075
# Epoch 16/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.0306
# Epoch 00016: val_loss improved from 1.00586 to 1.00110, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 156us/sample - loss: 1.0299 - val_loss: 1.0011
# Epoch 17/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 1.0284
# Epoch 00017: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 158us/sample - loss: 1.0300 - val_loss: 1.0158
# Epoch 18/100
# 13920/14152 [============================>.] - ETA: 0s - loss: 1.0224
# Epoch 00018: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 3s 191us/sample - loss: 1.0225 - val_loss: 1.0114
# Epoch 19/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 1.0104
# Epoch 00019: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 170us/sample - loss: 1.0111 - val_loss: 1.0148
# Epoch 20/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 0.9957
# Epoch 00020: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 156us/sample - loss: 0.9965 - val_loss: 1.0158
# Epoch 21/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.9859
# Epoch 00021: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 156us/sample - loss: 0.9859 - val_loss: 1.0135
# Epoch 22/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.9822
# Epoch 00022: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 161us/sample - loss: 0.9841 - val_loss: 1.0335
# Epoch 23/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 0.9809
# Epoch 00023: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 3s 214us/sample - loss: 0.9814 - val_loss: 1.0045
# Epoch 24/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 0.9703
# Epoch 00024: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 152us/sample - loss: 0.9696 - val_loss: 1.0108
# Epoch 25/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.9573
# Epoch 00025: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 154us/sample - loss: 0.9580 - val_loss: 1.0139
# Epoch 26/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 0.9437
# Epoch 00026: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 151us/sample - loss: 0.9476 - val_loss: 1.0034
# Epoch 27/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9480
# Epoch 00027: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 151us/sample - loss: 0.9455 - val_loss: 1.0312
# Epoch 28/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 0.9307
# Epoch 00028: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 152us/sample - loss: 0.9341 - val_loss: 1.0013
# Epoch 29/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9229
# Epoch 00029: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 152us/sample - loss: 0.9232 - val_loss: 1.0313
# Epoch 30/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.9155
# Epoch 00030: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 153us/sample - loss: 0.9163 - val_loss: 1.0042
# Epoch 31/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9078
# Epoch 00031: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 151us/sample - loss: 0.9082 - val_loss: 1.0213
# Epoch 32/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9038
# Epoch 00032: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 152us/sample - loss: 0.9026 - val_loss: 1.0241
# Epoch 33/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9062
# Epoch 00033: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 151us/sample - loss: 0.9059 - val_loss: 1.0282
# Epoch 34/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.8888
# Epoch 00034: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 151us/sample - loss: 0.8912 - val_loss: 1.0181
# Epoch 35/100
# 13920/14152 [============================>.] - ETA: 0s - loss: 0.8946
# Epoch 00035: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 153us/sample - loss: 0.8962 - val_loss: 1.0714
# Epoch 36/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 0.8816
# Epoch 00036: val_loss did not improve from 1.00110
# 14152/14152 [==============================] - 2s 154us/sample - loss: 0.8809 - val_loss: 1.0410
# Partial score of fold 1 is: 0.5787883285990895
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 200)               74000
# _________________________________________________________________
# layer_normalization_8 (Layer (None, 200)               400
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 100)               20100
# _________________________________________________________________
# layer_normalization_9 (Layer (None, 100)               200
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 50)                5050
# _________________________________________________________________
# layer_normalization_10 (Laye (None, 50)                100
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 25)                1275
# _________________________________________________________________
# layer_normalization_11 (Laye (None, 25)                50
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 101,201
# Trainable params: 101,201
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 14152 samples, validate on 3538 samples
# Epoch 1/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 1.9077
# Epoch 00001: val_loss improved from inf to 1.14163, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 197us/sample - loss: 1.8968 - val_loss: 1.1416
# Epoch 2/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 1.3560
# Epoch 00002: val_loss improved from 1.14163 to 1.08838, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 154us/sample - loss: 1.3520 - val_loss: 1.0884
# Epoch 3/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 1.2629
# Epoch 00003: val_loss improved from 1.08838 to 1.08656, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 155us/sample - loss: 1.2635 - val_loss: 1.0866
# Epoch 4/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 1.2089
# Epoch 00004: val_loss improved from 1.08656 to 1.07481, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 155us/sample - loss: 1.2077 - val_loss: 1.0748
# Epoch 5/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.1800
# Epoch 00005: val_loss improved from 1.07481 to 1.06379, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 154us/sample - loss: 1.1794 - val_loss: 1.0638
# Epoch 6/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.1531
# Epoch 00006: val_loss did not improve from 1.06379
# 14152/14152 [==============================] - 2s 153us/sample - loss: 1.1505 - val_loss: 1.0652
# Epoch 7/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.1548
# Epoch 00007: val_loss improved from 1.06379 to 1.05080, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 154us/sample - loss: 1.1546 - val_loss: 1.0508
# Epoch 8/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 1.1265
# Epoch 00008: val_loss improved from 1.05080 to 1.03901, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 157us/sample - loss: 1.1262 - val_loss: 1.0390
# Epoch 9/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.1082
# Epoch 00009: val_loss improved from 1.03901 to 1.02803, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 163us/sample - loss: 1.1087 - val_loss: 1.0280
# Epoch 10/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 1.0947
# Epoch 00010: val_loss did not improve from 1.02803
# 14152/14152 [==============================] - 2s 155us/sample - loss: 1.0945 - val_loss: 1.0305
# Epoch 11/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 1.0823
# Epoch 00011: val_loss did not improve from 1.02803
# 14152/14152 [==============================] - 2s 161us/sample - loss: 1.0825 - val_loss: 1.0308
# Epoch 12/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.0736
# Epoch 00012: val_loss improved from 1.02803 to 1.02605, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 157us/sample - loss: 1.0746 - val_loss: 1.0261
# Epoch 13/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.0567
# Epoch 00013: val_loss did not improve from 1.02605
# 14152/14152 [==============================] - 2s 161us/sample - loss: 1.0593 - val_loss: 1.0316
# Epoch 14/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.0460
# Epoch 00014: val_loss improved from 1.02605 to 1.02299, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 153us/sample - loss: 1.0435 - val_loss: 1.0230
# Epoch 15/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 1.0432
# Epoch 00015: val_loss did not improve from 1.02299
# 14152/14152 [==============================] - 2s 153us/sample - loss: 1.0445 - val_loss: 1.0306
# Epoch 16/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 1.0316
# Epoch 00016: val_loss improved from 1.02299 to 1.02234, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 154us/sample - loss: 1.0337 - val_loss: 1.0223
# Epoch 17/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.0132
# Epoch 00017: val_loss improved from 1.02234 to 1.00488, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 155us/sample - loss: 1.0159 - val_loss: 1.0049
# Epoch 18/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 1.0052
# Epoch 00018: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 154us/sample - loss: 1.0067 - val_loss: 1.0174
# Epoch 19/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 0.9982
# Epoch 00019: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 154us/sample - loss: 1.0008 - val_loss: 1.0066
# Epoch 20/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9836
# Epoch 00020: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 153us/sample - loss: 0.9813 - val_loss: 1.0153
# Epoch 21/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9740
# Epoch 00021: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 152us/sample - loss: 0.9737 - val_loss: 1.0302
# Epoch 22/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 0.9674
# Epoch 00022: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 154us/sample - loss: 0.9700 - val_loss: 1.0063
# Epoch 23/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.9640
# Epoch 00023: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 154us/sample - loss: 0.9641 - val_loss: 1.0165
# Epoch 24/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.9541
# Epoch 00024: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 153us/sample - loss: 0.9538 - val_loss: 1.0240
# Epoch 25/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9477
# Epoch 00025: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 153us/sample - loss: 0.9475 - val_loss: 1.0312
# Epoch 26/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9335
# Epoch 00026: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 153us/sample - loss: 0.9331 - val_loss: 1.0316
# Epoch 27/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.9396
# Epoch 00027: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 158us/sample - loss: 0.9389 - val_loss: 1.0270
# Epoch 28/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 0.9210
# Epoch 00028: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 156us/sample - loss: 0.9206 - val_loss: 1.0272
# Epoch 29/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 0.9148
# Epoch 00029: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 156us/sample - loss: 0.9170 - val_loss: 1.0287
# Epoch 30/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9108
# Epoch 00030: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 152us/sample - loss: 0.9103 - val_loss: 1.0296
# Epoch 31/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9057
# Epoch 00031: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 153us/sample - loss: 0.9054 - val_loss: 1.0502
# Epoch 32/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 0.8863
# Epoch 00032: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 152us/sample - loss: 0.8911 - val_loss: 1.0379
# Epoch 33/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 0.8866
# Epoch 00033: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 155us/sample - loss: 0.8860 - val_loss: 1.0397
# Epoch 34/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.8771
# Epoch 00034: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 152us/sample - loss: 0.8755 - val_loss: 1.0362
# Epoch 35/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.8641
# Epoch 00035: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 153us/sample - loss: 0.8625 - val_loss: 1.0506
# Epoch 36/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 0.8686
# Epoch 00036: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 161us/sample - loss: 0.8685 - val_loss: 1.0279
# Epoch 37/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.8631
# Epoch 00037: val_loss did not improve from 1.00488
# 14152/14152 [==============================] - 2s 154us/sample - loss: 0.8634 - val_loss: 1.0357
# Partial score of fold 2 is: 0.5812934107569538
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 200)               74000
# _________________________________________________________________
# layer_normalization_12 (Laye (None, 200)               400
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 100)               20100
# _________________________________________________________________
# layer_normalization_13 (Laye (None, 100)               200
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 50)                5050
# _________________________________________________________________
# layer_normalization_14 (Laye (None, 50)                100
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 25)                1275
# _________________________________________________________________
# layer_normalization_15 (Laye (None, 25)                50
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 101,201
# Trainable params: 101,201
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 14152 samples, validate on 3538 samples
# Epoch 1/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 1.7649
# Epoch 00001: val_loss improved from inf to 1.16612, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 203us/sample - loss: 1.7584 - val_loss: 1.1661
# Epoch 2/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 1.3531
# Epoch 00002: val_loss improved from 1.16612 to 1.09353, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 157us/sample - loss: 1.3527 - val_loss: 1.0935
# Epoch 3/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.2678
# Epoch 00003: val_loss improved from 1.09353 to 1.07553, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 160us/sample - loss: 1.2665 - val_loss: 1.0755
# Epoch 4/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 1.2138
# Epoch 00004: val_loss improved from 1.07553 to 1.06675, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 157us/sample - loss: 1.2159 - val_loss: 1.0668
# Epoch 5/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.1835
# Epoch 00005: val_loss improved from 1.06675 to 1.05550, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 154us/sample - loss: 1.1804 - val_loss: 1.0555
# Epoch 6/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.1665
# Epoch 00006: val_loss did not improve from 1.05550
# 14152/14152 [==============================] - 2s 152us/sample - loss: 1.1635 - val_loss: 1.0740
# Epoch 7/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 1.1490
# Epoch 00007: val_loss improved from 1.05550 to 1.04039, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 154us/sample - loss: 1.1501 - val_loss: 1.0404
# Epoch 8/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.1202
# Epoch 00008: val_loss did not improve from 1.04039
# 14152/14152 [==============================] - 2s 153us/sample - loss: 1.1198 - val_loss: 1.0481
# Epoch 9/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.1164
# Epoch 00009: val_loss did not improve from 1.04039
# 14152/14152 [==============================] - 2s 154us/sample - loss: 1.1168 - val_loss: 1.0415
# Epoch 10/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 1.1037
# Epoch 00010: val_loss did not improve from 1.04039
# 14152/14152 [==============================] - 2s 154us/sample - loss: 1.1010 - val_loss: 1.0491
# Epoch 11/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.0861
# Epoch 00011: val_loss improved from 1.04039 to 1.03274, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 156us/sample - loss: 1.0845 - val_loss: 1.0327
# Epoch 12/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 1.0816
# Epoch 00012: val_loss did not improve from 1.03274
# 14152/14152 [==============================] - 2s 153us/sample - loss: 1.0816 - val_loss: 1.0333
# Epoch 13/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.0747
# Epoch 00013: val_loss improved from 1.03274 to 1.02378, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 154us/sample - loss: 1.0738 - val_loss: 1.0238
# Epoch 14/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 1.0596
# Epoch 00014: val_loss did not improve from 1.02378
# 14152/14152 [==============================] - 2s 153us/sample - loss: 1.0569 - val_loss: 1.0295
# Epoch 15/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 1.0490
# Epoch 00015: val_loss did not improve from 1.02378
# 14152/14152 [==============================] - 2s 154us/sample - loss: 1.0495 - val_loss: 1.0304
# Epoch 16/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 1.0310
# Epoch 00016: val_loss improved from 1.02378 to 1.01374, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 155us/sample - loss: 1.0313 - val_loss: 1.0137
# Epoch 17/100
# 13920/14152 [============================>.] - ETA: 0s - loss: 1.0284
# Epoch 00017: val_loss improved from 1.01374 to 1.00614, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 157us/sample - loss: 1.0294 - val_loss: 1.0061
# Epoch 18/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 1.0178
# Epoch 00018: val_loss did not improve from 1.00614
# 14152/14152 [==============================] - 2s 153us/sample - loss: 1.0177 - val_loss: 1.0243
# Epoch 19/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 1.0118
# Epoch 00019: val_loss did not improve from 1.00614
# 14152/14152 [==============================] - 2s 153us/sample - loss: 1.0094 - val_loss: 1.0548
# Epoch 20/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.9995
# Epoch 00020: val_loss did not improve from 1.00614
# 14152/14152 [==============================] - 2s 154us/sample - loss: 0.9993 - val_loss: 1.0089
# Epoch 21/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.9947
# Epoch 00021: val_loss did not improve from 1.00614
# 14152/14152 [==============================] - 2s 152us/sample - loss: 0.9949 - val_loss: 1.0116
# Epoch 22/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9855
# Epoch 00022: val_loss improved from 1.00614 to 1.00342, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 153us/sample - loss: 0.9862 - val_loss: 1.0034
# Epoch 23/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9770
# Epoch 00023: val_loss did not improve from 1.00342
# 14152/14152 [==============================] - 2s 152us/sample - loss: 0.9765 - val_loss: 1.0047
# Epoch 24/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 0.9676
# Epoch 00024: val_loss improved from 1.00342 to 0.99665, saving model to nn_model.w8
# 14152/14152 [==============================] - 2s 154us/sample - loss: 0.9701 - val_loss: 0.9966
# Epoch 25/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9759
# Epoch 00025: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 175us/sample - loss: 0.9734 - val_loss: 1.0037
# Epoch 26/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 0.9499
# Epoch 00026: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 168us/sample - loss: 0.9487 - val_loss: 0.9994
# Epoch 27/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.9455
# Epoch 00027: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 173us/sample - loss: 0.9451 - val_loss: 1.0025
# Epoch 28/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.9421
# Epoch 00028: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 171us/sample - loss: 0.9428 - val_loss: 1.0018
# Epoch 29/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.9355
# Epoch 00029: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 163us/sample - loss: 0.9358 - val_loss: 0.9967
# Epoch 30/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 0.9210
# Epoch 00030: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 153us/sample - loss: 0.9205 - val_loss: 1.0282
# Epoch 31/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 0.9217
# Epoch 00031: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 157us/sample - loss: 0.9202 - val_loss: 1.0117
# Epoch 32/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9080
# Epoch 00032: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 152us/sample - loss: 0.9093 - val_loss: 1.0115
# Epoch 33/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9139
# Epoch 00033: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 151us/sample - loss: 0.9106 - val_loss: 1.0024
# Epoch 34/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 0.9016
# Epoch 00034: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 154us/sample - loss: 0.9030 - val_loss: 1.0123
# Epoch 35/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.8960
# Epoch 00035: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 153us/sample - loss: 0.8959 - val_loss: 1.0208
# Epoch 36/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 0.8872
# Epoch 00036: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 154us/sample - loss: 0.8862 - val_loss: 1.0172
# Epoch 37/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.8724
# Epoch 00037: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 152us/sample - loss: 0.8742 - val_loss: 1.0406
# Epoch 38/100
# 13792/14152 [============================>.] - ETA: 0s - loss: 0.8746
# Epoch 00038: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 153us/sample - loss: 0.8764 - val_loss: 1.0076
# Epoch 39/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.8678
# Epoch 00039: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 153us/sample - loss: 0.8674 - val_loss: 1.0391
# Epoch 40/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.8611
# Epoch 00040: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 152us/sample - loss: 0.8604 - val_loss: 1.0190
# Epoch 41/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.8542
# Epoch 00041: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 152us/sample - loss: 0.8584 - val_loss: 1.0815
# Epoch 42/100
# 13824/14152 [============================>.] - ETA: 0s - loss: 0.8532
# Epoch 00042: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 152us/sample - loss: 0.8514 - val_loss: 1.0188
# Epoch 43/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.8359
# Epoch 00043: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 153us/sample - loss: 0.8356 - val_loss: 1.0175
# Epoch 44/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.8419
# Epoch 00044: val_loss did not improve from 0.99665
# 14152/14152 [==============================] - 2s 154us/sample - loss: 0.8411 - val_loss: 1.0224
# Partial score of fold 3 is: 0.5884507883508521
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 200)               74000
# _________________________________________________________________
# layer_normalization_16 (Laye (None, 200)               400
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 100)               20100
# _________________________________________________________________
# layer_normalization_17 (Laye (None, 100)               200
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 50)                5050
# _________________________________________________________________
# layer_normalization_18 (Laye (None, 50)                100
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_23 (Dense)             (None, 25)                1275
# _________________________________________________________________
# layer_normalization_19 (Laye (None, 25)                50
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 101,201
# Trainable params: 101,201
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 14153 samples, validate on 3537 samples
# Epoch 1/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 1.9539
# Epoch 00001: val_loss improved from inf to 1.19020, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 194us/sample - loss: 1.9454 - val_loss: 1.1902
# Epoch 2/100
# 13824/14153 [============================>.] - ETA: 0s - loss: 1.4148
# Epoch 00002: val_loss improved from 1.19020 to 1.11020, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 152us/sample - loss: 1.4140 - val_loss: 1.1102
# Epoch 3/100
# 13824/14153 [============================>.] - ETA: 0s - loss: 1.3037
# Epoch 00003: val_loss improved from 1.11020 to 1.09243, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 153us/sample - loss: 1.3019 - val_loss: 1.0924
# Epoch 4/100
# 14048/14153 [============================>.] - ETA: 0s - loss: 1.2379
# Epoch 00004: val_loss did not improve from 1.09243
# 14153/14153 [==============================] - 2s 153us/sample - loss: 1.2387 - val_loss: 1.0957
# Epoch 5/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 1.2005
# Epoch 00005: val_loss improved from 1.09243 to 1.07665, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 152us/sample - loss: 1.1998 - val_loss: 1.0766
# Epoch 6/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 1.1714
# Epoch 00006: val_loss improved from 1.07665 to 1.06751, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 155us/sample - loss: 1.1735 - val_loss: 1.0675
# Epoch 7/100
# 14112/14153 [============================>.] - ETA: 0s - loss: 1.1481
# Epoch 00007: val_loss did not improve from 1.06751
# 14153/14153 [==============================] - 2s 158us/sample - loss: 1.1484 - val_loss: 1.0862
# Epoch 8/100
# 14144/14153 [============================>.] - ETA: 0s - loss: 1.1356
# Epoch 00008: val_loss improved from 1.06751 to 1.05614, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 153us/sample - loss: 1.1356 - val_loss: 1.0561
# Epoch 9/100
# 14112/14153 [============================>.] - ETA: 0s - loss: 1.1265
# Epoch 00009: val_loss improved from 1.05614 to 1.04804, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 162us/sample - loss: 1.1271 - val_loss: 1.0480
# Epoch 10/100
# 14048/14153 [============================>.] - ETA: 0s - loss: 1.1100
# Epoch 00010: val_loss did not improve from 1.04804
# 14153/14153 [==============================] - 2s 154us/sample - loss: 1.1105 - val_loss: 1.0528
# Epoch 11/100
# 14016/14153 [============================>.] - ETA: 0s - loss: 1.1114
# Epoch 00011: val_loss improved from 1.04804 to 1.02448, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 216us/sample - loss: 1.1101 - val_loss: 1.0245
# Epoch 12/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 1.0825
# Epoch 00012: val_loss did not improve from 1.02448
# 14153/14153 [==============================] - 2s 152us/sample - loss: 1.0816 - val_loss: 1.0361
# Epoch 13/100
# 14144/14153 [============================>.] - ETA: 0s - loss: 1.0732
# Epoch 00013: val_loss did not improve from 1.02448
# 14153/14153 [==============================] - 2s 155us/sample - loss: 1.0731 - val_loss: 1.0359
# Epoch 14/100
# 14144/14153 [============================>.] - ETA: 0s - loss: 1.0549
# Epoch 00014: val_loss did not improve from 1.02448
# 14153/14153 [==============================] - 2s 157us/sample - loss: 1.0546 - val_loss: 1.0563
# Epoch 15/100
# 13824/14153 [============================>.] - ETA: 0s - loss: 1.0361
# Epoch 00015: val_loss did not improve from 1.02448
# 14153/14153 [==============================] - 2s 152us/sample - loss: 1.0383 - val_loss: 1.0336
# Epoch 16/100
# 14048/14153 [============================>.] - ETA: 0s - loss: 1.0406
# Epoch 00016: val_loss did not improve from 1.02448
# 14153/14153 [==============================] - 2s 155us/sample - loss: 1.0411 - val_loss: 1.0679
# Epoch 17/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 1.0237
# Epoch 00017: val_loss improved from 1.02448 to 1.01883, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 154us/sample - loss: 1.0251 - val_loss: 1.0188
# Epoch 18/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 1.0127
# Epoch 00018: val_loss improved from 1.01883 to 1.01688, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 153us/sample - loss: 1.0137 - val_loss: 1.0169
# Epoch 19/100
# 14048/14153 [============================>.] - ETA: 0s - loss: 1.0161
# Epoch 00019: val_loss did not improve from 1.01688
# 14153/14153 [==============================] - 2s 153us/sample - loss: 1.0161 - val_loss: 1.0378
# Epoch 20/100
# 13824/14153 [============================>.] - ETA: 0s - loss: 0.9985
# Epoch 00020: val_loss did not improve from 1.01688
# 14153/14153 [==============================] - 2s 152us/sample - loss: 0.9985 - val_loss: 1.0194
# Epoch 21/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 0.9874
# Epoch 00021: val_loss improved from 1.01688 to 1.00611, saving model to nn_model.w8
# 14153/14153 [==============================] - 2s 153us/sample - loss: 0.9871 - val_loss: 1.0061
# Epoch 22/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 0.9869
# Epoch 00022: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 151us/sample - loss: 0.9840 - val_loss: 1.0388
# Epoch 23/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 0.9664
# Epoch 00023: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 151us/sample - loss: 0.9662 - val_loss: 1.0204
# Epoch 24/100
# 14112/14153 [============================>.] - ETA: 0s - loss: 0.9711
# Epoch 00024: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 153us/sample - loss: 0.9710 - val_loss: 1.0136
# Epoch 25/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 0.9684
# Epoch 00025: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 151us/sample - loss: 0.9673 - val_loss: 1.0190
# Epoch 26/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 0.9510
# Epoch 00026: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 151us/sample - loss: 0.9514 - val_loss: 1.0205
# Epoch 27/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 0.9386
# Epoch 00027: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 151us/sample - loss: 0.9404 - val_loss: 1.0180
# Epoch 28/100
# 13888/14153 [============================>.] - ETA: 0s - loss: 0.9245
# Epoch 00028: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 154us/sample - loss: 0.9259 - val_loss: 1.0295
# Epoch 29/100
# 14080/14153 [============================>.] - ETA: 0s - loss: 0.9423
# Epoch 00029: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 154us/sample - loss: 0.9431 - val_loss: 1.0146
# Epoch 30/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 0.9157
# Epoch 00030: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 151us/sample - loss: 0.9158 - val_loss: 1.0225
# Epoch 31/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 0.9052
# Epoch 00031: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 151us/sample - loss: 0.9075 - val_loss: 1.0078
# Epoch 32/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 0.9032
# Epoch 00032: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 151us/sample - loss: 0.9060 - val_loss: 1.0224
# Epoch 33/100
# 14048/14153 [============================>.] - ETA: 0s - loss: 0.8988
# Epoch 00033: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 158us/sample - loss: 0.9007 - val_loss: 1.0127
# Epoch 34/100
# 13888/14153 [============================>.] - ETA: 0s - loss: 0.9004
# Epoch 00034: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 167us/sample - loss: 0.8989 - val_loss: 1.0316
# Epoch 35/100
# 13920/14153 [============================>.] - ETA: 0s - loss: 0.8831
# Epoch 00035: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 157us/sample - loss: 0.8821 - val_loss: 1.0132
# Epoch 36/100
# 13824/14153 [============================>.] - ETA: 0s - loss: 0.8801
# Epoch 00036: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 157us/sample - loss: 0.8789 - val_loss: 1.0123
# Epoch 37/100
# 14112/14153 [============================>.] - ETA: 0s - loss: 0.8726
# Epoch 00037: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 152us/sample - loss: 0.8728 - val_loss: 1.0241
# Epoch 38/100
# 14016/14153 [============================>.] - ETA: 0s - loss: 0.8699
# Epoch 00038: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 154us/sample - loss: 0.8710 - val_loss: 1.0182
# Epoch 39/100
# 14112/14153 [============================>.] - ETA: 0s - loss: 0.8654
# Epoch 00039: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 153us/sample - loss: 0.8641 - val_loss: 1.0308
# Epoch 40/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 0.8467
# Epoch 00040: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 152us/sample - loss: 0.8490 - val_loss: 1.0292
# Epoch 41/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 0.8541
# Epoch 00041: val_loss did not improve from 1.00611
# 14153/14153 [==============================] - 2s 151us/sample - loss: 0.8506 - val_loss: 1.0309
# Partial score of fold 4 is: 0.576906905722183
# Our oof cohen kappa score is:  0.5832203577528756

# %%
weights = {'lbg': 0.60, 'cat': 0, 'xgb': 0.20, 'nn': 0.20}

final_pred = (lgb_model.y_pred * weights['lbg']) + (xgb_model.y_pred * weights['xgb']) + (nn_model.y_pred * weights['nn'])
#final_pred = cnn_model.y_pred
print(final_pred.shape)
# Out:
# (1000,)

# %%
#pd.DataFrame([(round(a, 2), round(b, 2), round(c, 2), round(d, 2)) for a, b, c, d in zip(lgb_model.y_pred, cat_model.y_pred, xgb_model.y_pred, nn_model.y_pred)], columns=['lgb', 'cat', 'xgb', 'nn']).head(50)

# %%
dist = Counter(reduce_train['accuracy_group'])
for k in dist:
    dist[k] /= len(reduce_train)
reduce_train['accuracy_group'].hist()

acum = 0
bound = {}
for i in range(3):
    acum += dist[i]
    bound[i] = np.percentile(final_pred, acum * 100)
print(bound)

def classify(x):
    if x <= bound[0]:
        return 0
    elif x <= bound[1]:
        return 1
    elif x <= bound[2]:
        return 2
    else:
        return 3
    
final_pred = np.array(list(map(classify, final_pred)))

sample_submission['accuracy_group'] = final_pred.astype(int)
sample_submission.to_csv('submission.csv', index=False)
sample_submission['accuracy_group'].value_counts(normalize=True)
# Out:
# {0: 1.2874460789486735, 1: 1.6980827678689754, 2: 1.946033314362323}
# 3    0.500
# 0    0.239
# 1    0.136
# 2    0.125
# Name: accuracy_group, dtype: float64
